# %% [markdown]
# Authors = [
#     "Dhruba Pujary (11576200)",
#     "Tarun Krishna (11593040)"
# ]

# %%
import numpy as np
import bz2
import os
from collections import defaultdict
import json
from scipy import stats
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10, 10)

# %%
# define function to read pre-trained embeddings
def read_embedding(file_name):
    embedding=np.array([])
    w2i = defaultdict(lambda: len(w2i))
    with bz2.BZ2File(file_name, 'r') as datum:
        
        for iter_, line in enumerate(datum):
            
            if (iter_)%10000==0:
                print("Read {} lines".format(iter_))
                            
            line = line.strip().split()
            w2i[line[0].decode('UTF-8')]
            if iter_==0:
                embedding = np.array(list(map(float, line[1:])))
            else:
                embed = np.array(list(map(float, line[1:])))
                embedding = np.vstack((embedding, embed))
    return w2i, embedding

# %%
def load_model(model_name):
    model_path = 'model/{}'.format(model_name)
    if not os.path.isfile(model_path+'.npz'):
        print('reading embedding file')
        w2i, embedding = read_embedding("data/{}.bz2".format(model_name))
        
        norm_m = np.linalg.norm(embedding,axis=1,keepdims=True)
        
        datum ={"word_id":w2i, 'embedding':embedding, 'norm':norm_m}
        #save word indexes         
        with open(model_path+'.json', 'w') as outfile:  
            json.dump(w2i, outfile, indent=4)
        #
        np.savez(model_path+'.npz',embedding=embedding, norm_m=norm_m)
        
    else:
            print("loading Word-embeddings")
            with open(model_path+'.json') as json_file:  
                w2ind = json.load(json_file)
            data = np.load(model_path+'.npz')
            embedding, norm_m = data['embedding'], data['norm_m']
            data.close()
            print("done!!")
    return w2ind, embedding, norm_m

# %%
def index2word(w2i):
    i2w = dict()
    for key, value in w2i.items():
        i2w[value] = key
    return i2w

# %%
evaluation_data = ["data/SimLex-999","data/MEN"]

# %%
#Read SimLex-999
def simLex(filename):
    simlex_w = []
    dist_word = {}
    pair = []
    with open(filename, 'rb') as datum:
        data =datum.readlines()
        
    for _, line in enumerate(data[1:]):
        line = line.strip().split()
               
        pair = [(line[0].decode('UTF-8'), line[1].decode('UTF-8')),\
                (line[1].decode('UTF-8'), line[0].decode('UTF-8'))]
        for ind, word in enumerate(pair[:1]):
            simlex_w.append(word[0])
            simlex_w.append(word[1])
            if word[0] not in dist_word.keys():
                dist_word[word[0]] = []
                
            dist_word[word[0]].append((word[1], float(line[3])/10))
             
    #Sort the list
    for key, val in dist_word.items():
        val.sort(key=lambda _ : _[1], reverse=True)
    
    simlex_w = set(simlex_w)
    return dist_word, list(set(simlex_w))       
        
simlex, simlex_w = simLex("data/SimLex-999/SimLex-999.txt")

# %%
print(len(simlex.keys()),len(simlex_w))
# Out:
# 616 1028

# %%
# Read MEN
def men_(filename):
    men_w=[]
    dist_word = {}
    norm_word = {}
    pair = []
    with open(filename, 'rb') as datum:
        data =datum.readlines()
        
    for _, line in enumerate(data):
        line = line.strip().split()
                             
        pair = [(line[0].decode('UTF-8'), line[1].decode('UTF-8')),\
                (line[1].decode('UTF-8'), line[0].decode('UTF-8'))]
        for ind, word in enumerate(pair[:1]):
            men_w.append(word[0])
            men_w.append(word[1])
            if word[0] not in dist_word.keys():
                dist_word[word[0]] = []
                norm_word[word[0]] = []
            dist_word[word[0]].append((word[1], float(line[2])))
    
    #normalizing scores in [0,1]
    for key, value in dist_word.items():
        normalized_sum = 0.0
        for _, score in value:
            normalized_sum += score
        for w, score in value:
            score = round(score/normalized_sum, 3)
            norm_word[key].append((w, score))
   
    #Sort the list
    for key, val in norm_word.items():
       
        val.sort(key=lambda _ : _[1], reverse=True)
    
    men_w = set(men_w)
    return dist_word, list(men_w)       
        
men, men_w = men_("data/MEN/MEN_dataset_natural_form_full")

# %%
np.intersect1d(simlex_w,men_w)
# Out:
# array(['action', 'air', 'airport', 'alley', 'ancient', 'apartment',
#        'apple', 'arrow', 'baby', 'bacon', 'bag', 'ball', 'band', 'bar',
#        'barn', 'baseball', 'basket', 'bath', 'bathroom', 'beach',
#        'beauty', 'bed', 'bedroom', 'beef', 'beer', 'belly', 'bench',
#        'bible', 'bicycle', 'birthday', 'boat', 'body', 'book', 'bottle',
#        'bread', 'breakfast', 'brick', 'bride', 'bridge', 'bus', 'button',
#        'camera', 'candy', 'canyon', 'car', 'card', 'cat', 'cathedral',
#        'cattle', 'ceiling', 'chair', 'chapel', 'chicken', 'chocolate',
#        'church', 'cigarette', 'cliff', 'clothes', 'cloud', 'club',
#        'coast', 'cocktail', 'coffee', 'computer', 'cone', 'construction',
#        'cop', 'cottage', 'couple', 'cow', 'crystal', 'curve', 'daughter',
#        'dawn', 'day', 'decoration', 'diamond', 'dinner', 'dirt', 'dirty',
#        'dog', 'door', 'dusk', 'engine', 'evening', 'fabric', 'fashion',
#        'fence', 'flight', 'floor', 'fog', 'fun', 'furniture', 'game',
#        'garden', 'gate', 'glass', 'grass', 'guitar', 'gun', 'guy', 'hand',
#        'happy', 'hat', 'hawk', 'head', 'heart', 'highway', 'hill', 'home',
#        'horse', 'hotel', 'house', 'ice', 'idea', 'iron', 'jacket',
#        'journal', 'key', 'kitchen', 'lady', 'lake', 'lamb', 'leg', 'lens',
#        'lion', 'lunch', 'machine', 'man', 'maple', 'meat', 'metal',
#        'milk', 'mist', 'monster', 'moon', 'morning', 'moss', 'mother',
#        'motor', 'mountain', 'movie', 'mud', 'muscle', 'music', 'new',
#        'night', 'oak', 'ocean', 'old', 'organ', 'palm', 'paper', 'parade',
#        'party', 'people', 'person', 'plane', 'rabbit', 'rail', 'rain',
#        'reflection', 'rice', 'river', 'roof', 'room', 'salad', 'sandwich',
#        'school', 'sea', 'seed', 'sheep', 'shore', 'sky', 'snow', 'son',
#        'soup', 'storm', 'stream', 'street', 'summer', 'sun', 'sunrise',
#        'sunset', 'sunshine', 'taxi', 'tea', 'television', 'tongue',
#        'tower', 'tree', 'valley', 'vehicle', 'violet', 'wall', 'water',
#        'weather', 'window', 'wine', 'winter', 'wire', 'wood'],
#       dtype='<U14')

# %%
si = [i for i in simlex.keys()]
me = [i for i in men.keys()]

inter = np.intersect1d(si,me)
print(inter)
# Out:
# ['action' 'air' 'alley' 'apartment' 'apple' 'baby' 'bacon' 'ball' 'band'
#  'bar' 'bath' 'bathroom' 'beach' 'beauty' 'bed' 'beer' 'belly' 'bible'
#  'bicycle' 'birthday' 'boat' 'body' 'book' 'bottle' 'bread' 'breakfast'
#  'bride' 'camera' 'canyon' 'car' 'card' 'cat' 'cattle' 'ceiling' 'chair'
#  'chicken' 'chocolate' 'church' 'cliff' 'clothes' 'cloud' 'club' 'cop'
#  'cottage' 'couple' 'cow' 'curve' 'daughter' 'day' 'dinner' 'dirty' 'dog'
#  'door' 'evening' 'floor' 'fun' 'game' 'glass' 'grass' 'guitar' 'gun'
#  'guy' 'hand' 'happy' 'hat' 'heart' 'hill' 'home' 'horse' 'house' 'idea'
#  'lady' 'lake' 'leg' 'lens' 'machine' 'man' 'meat' 'metal' 'milk'
#  'monster' 'moon' 'mother' 'motor' 'mountain' 'movie' 'mud' 'muscle'
#  'music' 'night' 'oak' 'old' 'paper' 'people' 'plane' 'rail' 'rain' 'rice'
#  'river' 'roof' 'room' 'salad' 'school' 'sea' 'seed' 'shore' 'sky' 'snow'
#  'storm' 'street' 'sun' 'tree']

# %%
print(simlex["beach"])
print()
print(men["beach"])
# Out:
# [('seashore', 0.833), ('island', 0.5599999999999999), ('sea', 0.46799999999999997), ('reef', 0.377)]
#
# [('sand', 48.0), ('sea', 44.0), ('shore', 42.0), ('coast', 42.0), ('harbour', 41.0), ('swimming', 40.0), ('holiday', 35.0), ('scenery', 34.0), ('cliff', 33.0), ('pebbles', 30.0)]

# %%
eval_data = [(simlex, simlex_w,'SimLex-999'),(men, men_w, "MEN")]

# %%
# get all the word_embedding for particular dataset
def get_embedd(w2ind, embedding,norm_m, eval_word):
    word_id = []
    emb_word =[]
    
    w2i_eval =defaultdict(lambda: len(w2i_eval))
#     print("Total words in given data {}".format(len(eval_word)))
    for i,w in enumerate(eval_word):
        if w in w2ind.keys():
            
            word_id.append(w2ind[w])
            w2i_eval[w]
        else:
            continue
            print("word <==>{}<==> does not have embedding ".format(w))
    embedd_eval = embedding[word_id]
    norm_eval = norm_m[word_id]
#     print("Total words with their embedding are {}".format(len(w2i_eval.keys())))
    return embedd_eval, w2i_eval,norm_eval

# %%
# evaluate the model on both data_sets
def wordSim(w2ind, embedd_eval,  w2i_eval,norm_eval,embedding, word=None, n=None):
        
        word_vec = embedding[w2ind[word]]
#         print(word_vec.shape, embedd_eval.shape)
        score = np.dot(embedd_eval, word_vec)
        score = np.reshape(score, (len(score),1))*(1./norm_eval)*(1/np.linalg.norm(word_vec))
#         print(w2i_eval[word])
        ranking = [(key, round(score[w2i_eval[key]][0],4)) for key in w2i_eval.keys()]
#         print(ranking[0])
        ranking.sort(key=lambda _:_[1], reverse=True)
        #return from index 1 becoz highest score will the score of word with itself
        ranking = ranking[1:]
        return ranking[0:n]

# %%
def cal_coeff(eval_data, w2ind, embedding, norm_m, name=None):
    for item in eval_data[:]:
        print("running {} data".format(item[2]))
        eval_rank, eval_word = item[0], item[1]
        #print(len(eval_rank), len(eval_word))
        a = []
        b = []
        e_embed,w2i_eval, e_norm  = get_embedd(w2ind, embedding, norm_m, eval_word)

        #iterate over words in the evalution data to get similarity 
        for ind, word in enumerate(eval_rank.keys()):
            if word not in w2i_eval.keys():

                continue

            n = len(eval_rank[word])
            
            #get top-n ranking from trained embeddings from evalution data         
            score = wordSim(w2ind, e_embed, w2i_eval, e_norm, embedding, word)
            w_found  =[]
            for w, sc_ in eval_rank[word]:
                a.append(round(sc_, 3))
                w_found.append(w)
                       
            for w in w_found:
                for wskr_pair in score:
                    if w in wskr_pair:
                        b.append(wskr_pair[1]) 
            

        a, b = np.array(a), np.array(b)
        rho, _ = stats.spearmanr(a, b, axis = None)
        val, _ = stats.pearsonr(a, b)
        print()
        print(item[2], "<<<--->>>  ",name, "<---->"," Pearson Correlation ", round(val,4) )
        print(item[2], "<<<--->>>  ",name, "<---->"," Spearman Correlation ", round(rho,4) )
        print()
            
        plt.figure()
        plt.scatter(a, b)
        m,c = np.polyfit(a, b, 1) 

        plt.plot(a, m*np.array(a)+c, 'r--')
        plt.title(name)
        plt.grid(True)
        plt.show()

# %%
w2ind, embedding, norm_m = load_model('bow2.words') 
cal_coeff(eval_data, w2ind, embedding, norm_m, "bow2 embeddings")
del w2ind
del embedding
# Out:
# loading Word-embeddings
# done!!
# running SimLex-999 data
#
# SimLex-999 <<<--->>>   bow2 embeddings <---->  Pearson Correlation  0.4285
# SimLex-999 <<<--->>>   bow2 embeddings <---->  Spearman Correlation  0.4141
# running MEN data
#
# MEN <<<--->>>   bow2 embeddings <---->  Pearson Correlation  0.6777
# MEN <<<--->>>   bow2 embeddings <---->  Spearman Correlation  0.6999

# %%
w2ind, embedding, norm_m = load_model('bow5.words') 
cal_coeff(eval_data, w2ind, embedding, norm_m, "bow5 embeddings")
del w2ind
del embedding
# Out:
# loading Word-embeddings
# done!!
# running SimLex-999 data
#
# SimLex-999 <<<--->>>   bow5 embeddings <---->  Pearson Correlation  0.3756
# SimLex-999 <<<--->>>   bow5 embeddings <---->  Spearman Correlation  0.3674
# running MEN data
#
# MEN <<<--->>>   bow5 embeddings <---->  Pearson Correlation  0.7082
# MEN <<<--->>>   bow5 embeddings <---->  Spearman Correlation  0.7232

# %%
w2ind, embedding, norm_m = load_model('deps.words') 
cal_coeff(eval_data, w2ind, embedding, norm_m, "dependence embeddings")
del w2ind
del embedding
# Out:
# loading Word-embeddings
# done!!
# running SimLex-999 data
#
# SimLex-999 <<<--->>>   dependence embeddings <---->  Pearson Correlation  0.4619
# SimLex-999 <<<--->>>   dependence embeddings <---->  Spearman Correlation  0.4457
# running MEN data
#
# MEN <<<--->>>   dependence embeddings <---->  Pearson Correlation  0.5974
# MEN <<<--->>>   dependence embeddings <---->  Spearman Correlation  0.6178

# %% [markdown]
# #### Analogy

# %%
def load_test(file_name):
    # read the test file and return the processed data
    # input:
    # file_name: input file name
    # output: list of list of queries in the format [a,b,c,d] for a:b::c:d analogy task
    with open(file_name, 'r') as f:
        t_lines = f.read().lower().split('\n')

    analogy = list(map(lambda x: x.split(), t_lines[0:]))

    return analogy

# %%
analogy = load_test('data/questions-words.txt')

def segmentData(analogy):
    
    analogy_dict = dict()
    dummy_list = []
    key = []
    for index, item in enumerate(analogy):
        if len(item) > 0 and item[0] == ':':
            analogy_dict[''.join(key)] = dummy_list
            key = item
            dummy_list = []
            continue
        dummy_list.append(item)
    
    analogy_dict[''.join(key)] = dummy_list
    
    return analogy_dict

analogy_dict = segmentData(analogy)

# %%
def predict_analogy(analogy, w2i, i2w, embedding, norm_m):

    mean_rr = 0
    mean_rr_w = 0
    correct = 0
    correct_w = 0
    predict_list = dict()

    for index, item in enumerate(analogy):
        num_items = len(item)
        if num_items > 0 and item[0] in w2i.keys():
            a_i = w2i[item[0]]
            a_emd = embedding[a_i]/norm_m[a_i]
        else:
            continue

        if num_items > 1 and item[1] in w2i.keys():
            b_i = w2i[item[1]]
            b_emd = embedding[b_i]/norm_m[b_i]
        else:
            continue

        if num_items > 2 and item[2] in w2i.keys():
            c_i = w2i[item[2]]
            c_emd = embedding[c_i]/norm_m[c_i]
        else:
            continue

        if num_items > 3 and item[3] in w2i.keys():
            d_i = w2i[item[3]]
        else:
            continue

        v = b_emd - a_emd

        d_test = c_emd + v
        d_test = d_test/ np.linalg.norm(d_test)
        
        cos_sim = np.dot(embedding, d_test)

        cos_sim = np.reshape(cos_sim, (1, -1))
        cos_sim = cos_sim.tolist()

        ranked_index = sorted(range(len(cos_sim[0])), key=lambda k: cos_sim[0][k], reverse=True)

        word_rank = [i+1 for i, word_i in enumerate(ranked_index) if word_i == d_i]
        word_rank_w = [i+1 for i, word_i in enumerate(ranked_index) if (word_i == d_i or word_i == a_i or word_i == b_i or word_i == c_i) and (word_rank[0] > i)]
        predict_list[(':').join(item)] = [str(i2w[word_i]) for i, word_i in enumerate(ranked_index) if i < word_rank[0] and word_i in i2w.keys()]

        mean_rr += 1/word_rank[0]

        if len(word_rank_w) > 1:
            mean_rr_w += 1/(word_rank[0] - len(word_rank_w) + 1)

        if d_i == ranked_index[0]:
            correct += 1
        else:
            if d_i == ranked_index[len(word_rank_w) - 1]:
                correct_w += 1

    mean_rr = mean_rr/len(analogy)
    mean_rr_w = mean_rr_w/len(analogy)

    accuracy = correct/len(analogy)
    accuracy_w = (correct + correct_w)/len(analogy)

    return mean_rr, mean_rr_w, accuracy, accuracy_w, predict_list

# %%
analogy = load_test('data/questions-words.txt')

file_name = 'deps.words'
w2i, embedding, norm_m = load_model(file_name)
i2w = index2word(w2i)

mean_rr1, mean_rr_w1, accuracy1, accuracy_w1, predict_list = predict_analogy(analogy, w2i, i2w, embedding, norm_m)
# Out:
# loading Word-embeddings
# done!!

# %%
print("{0:15s}{1:10s}{2:10s}{3:10s}{4:10s}".format("","MRR","MRR 2","Accuracy","Accuracy 2"))
print("{0:10s}{1:10.3}{2:10.3}{3:10.3}{4:15.5}".format("Dependency",mean_rr1,mean_rr_w1,accuracy1,accuracy_w1))
# Out:
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.237     0.411    0.0264        0.36062

# %%
analogy = load_test('data/questions-words.txt')

file_name = 'bow2.words'
w2i, embedding, norm_m = load_model(file_name)
i2w = index2word(w2i)

mean_rr2, mean_rr_w2, accuracy2, accuracy_w2, predict_list = predict_analogy(analogy, w2i, i2w, embedding, norm_m)
# Out:
# loading Word-embeddings
# done!!

# %%
print("{0:15s}{1:10s}{2:10s}{3:10s}{4:10s}".format("","MRR","MRR 2","Accuracy","Accuracy 2"))
print("{0:10s}{1:10.3}{2:10.3}{3:10.3}{4:15.5}".format("Bow2",mean_rr2,mean_rr_w2,accuracy2,accuracy_w2))
# Out:
#                MRR       MRR 2     Accuracy  Accuracy 2
# Bow2           0.367     0.575    0.0873         0.5838

# %%
analogy = load_test('data/questions-words.txt')

file_name = 'bow5.words'
w2i, embedding, norm_m = load_model(file_name)
i2w = index2word(w2i)

mean_rr3, mean_rr_w3, accuracy3, accuracy_w3, predict_list = predict_analogy(analogy, w2i, i2w, embedding, norm_m)
# Out:
# loading Word-embeddings
# done!!

# %%
print("{0:15s}{1:10s}{2:10s}{3:10s}{4:10s}".format("","MRR","MRR 2","Accuracy","Accuracy 2"))
print("{0:10s}{1:10.3}{2:10.3}{3:10.3}{4:15.5}".format("Bow5",mean_rr3,mean_rr_w3,accuracy3,accuracy_w3))
# Out:
#                MRR       MRR 2     Accuracy  Accuracy 2
# Bow5           0.407     0.597     0.102        0.61325

# %%
file_name = 'deps.words'
w2i, embedding, norm_m = load_model(file_name)
i2w = index2word(w2i)

for index,item in enumerate(analogy_dict):
    print(item)
    if len(analogy_dict[item]) < 1:
        continue
    mean_rr4, mean_rr_w4, accuracy4, accuracy_w4, predict_list = predict_analogy(analogy_dict[item], w2i, i2w, embedding, norm_m)
    print("{0:15s}{1:10s}{2:10s}{3:10s}{4:10s}".format("","MRR","MRR 2","Accuracy","Accuracy 2"))
    print("{0:10s}{1:10.3}{2:10.3}{3:10.3}{4:15.5}".format("Dependency",mean_rr4,mean_rr_w4,accuracy4,accuracy_w4))
    
    with open(file_name+str(index),'w',encoding="utf-8") as pred_file:
        pred_file.write(str(predict_list))
# Out:
# loading Word-embeddings
# done!!
#
# :capital-common-countries
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.215     0.492   0.00198        0.35178
# :capital-world
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.108     0.202   0.00177        0.11207
# :currency
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency    0.0421    0.0585   0.00693        0.04388
# :city-in-state
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency      0.11     0.221       0.0        0.12282
# :family
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.478     0.763    0.0909        0.81621
# :gram1-adjective-to-adverb
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency    0.0426    0.0599   0.00504       0.034274
# :gram2-opposite
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.246     0.476       0.0        0.40025
# :gram3-comparative
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.461     0.775    0.0788        0.80105
# :gram4-superlative
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.311     0.552    0.0472        0.52763
# :gram5-present-participle
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.403     0.705     0.035        0.64678
# :gram6-nationality-adjective
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.137     0.214   0.00563        0.12133
# :gram7-past-tense
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.402     0.683    0.0487        0.65897
# :gram8-plural
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency       0.4     0.716    0.0315        0.67568
# :gram9-plural-verbs
#                MRR       MRR 2     Accuracy  Accuracy 2
# Dependency     0.553     0.798     0.147         0.9092

# %%
file_name = 'bow2.words'
w2i, embedding, norm_m = load_model(file_name)
i2w = index2word(w2i)

for index,item in enumerate(analogy_dict):
    print(item)
    if len(analogy_dict[item]) < 1:
        continue
    mean_rr4, mean_rr_w4, accuracy4, accuracy_w4, predict_list = predict_analogy(analogy_dict[item], w2i, i2w, embedding, norm_m)
    print("{0:15s}{1:10s}{2:10s}{3:10s}{4:10s}".format("","MRR","MRR 2","Accuracy","Accuracy 2"))
    print("{0:10s}{1:10.3}{2:10.3}{3:10.3}{4:15.5}".format("BOW2",mean_rr4,mean_rr_w4,accuracy4,accuracy_w4))
    
    with open(file_name+str(index),'w',encoding="utf-8") as pred_file:
        pred_file.write(str(predict_list))
# Out:
# loading Word-embeddings
# done!!
#
# :capital-common-countries
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.546     0.651     0.229        0.83597
# :capital-world
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.376     0.659    0.0597        0.63019
# :currency
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2          0.0639    0.0996   0.00924       0.084296
# :city-in-state
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.198     0.497  0.000811        0.39238
# :family
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.492     0.729     0.123        0.79447
# :gram1-adjective-to-adverb
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.114     0.234   0.00202        0.15927
# :gram2-opposite
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.212     0.414   0.00985        0.35591
# :gram3-comparative
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.538     0.808     0.131        0.89565
# :gram4-superlative
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.354      0.65    0.0365        0.59358
# :gram5-present-participle
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.399     0.708    0.0388        0.62689
# :gram6-nationality-adjective
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.678     0.265     0.527        0.74171
# :gram7-past-tense
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.349     0.643    0.0192        0.55705
# :gram8-plural
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.403      0.78    0.0128        0.73273
# :gram9-plural-verbs
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW2           0.492     0.756     0.109         0.8069

# %%
file_name = 'bow5.words'
w2i, embedding, norm_m = load_model(file_name)
i2w = index2word(w2i)

for index,item in enumerate(analogy_dict):
    print(item)
    if len(analogy_dict[item]) < 1:
        continue
    mean_rr4, mean_rr_w4, accuracy4, accuracy_w4, predict_list = predict_analogy(analogy_dict[item], w2i, i2w, embedding, norm_m)
    print("{0:15s}{1:10s}{2:10s}{3:10s}{4:10s}".format("","MRR","MRR 2","Accuracy","Accuracy 2"))
    print("{0:10s}{1:10.3}{2:10.3}{3:10.3}{4:15.5}".format("BOW5",mean_rr4,mean_rr_w4,accuracy4,accuracy_w4))
    
    with open(file_name+str(index),'w',encoding="utf-8") as pred_file:
        pred_file.write(str(predict_list))
# Out:
# loading Word-embeddings
# done!!
#
# :capital-common-countries
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.596     0.741     0.223        0.94071
# :capital-world
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5            0.44      0.74    0.0588        0.70292
# :currency
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5          0.0775     0.101    0.0231       0.091224
# :city-in-state
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.309      0.61    0.0113        0.51277
# :family
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.523     0.697     0.172        0.81818
# :gram1-adjective-to-adverb
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5            0.14     0.267   0.00504        0.16935
# :gram2-opposite
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.219     0.415    0.0172         0.3633
# :gram3-comparative
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.549      0.69     0.198        0.83033
# :gram4-superlative
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.337     0.615    0.0419        0.53743
# :gram5-present-participle
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.417     0.755    0.0265        0.67045
# :gram6-nationality-adjective
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.742     0.255     0.595        0.82364
# :gram7-past-tense
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.362     0.645    0.0212        0.54679
# :gram8-plural
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.398     0.727    0.0248        0.66817
# :gram9-plural-verbs
#                MRR       MRR 2     Accuracy  Accuracy 2
# BOW5           0.481     0.705     0.116        0.73563

# %% [markdown]
# **Clustering word vectors**

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import random
plt.rcParams["figure.figsize"] = (20, 20)

# %%
with open('data/2000_nouns_sorted.txt', 'r')as dat_file:
    nouns = dat_file.read().strip().split('\n')
    
nouns = list(set(map(lambda _:_.strip(), nouns)))
random.shuffle(nouns)

# %%
def tsne_viz(embed_):
    print("Performing t-SNE")
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=500, random_state=23)
    vis_data = tsne_model.fit_transform(embed_)
    print("\t... done")
    
    return vis_data
    

def get_viz(w2_, emb_, n_m, nouns, num_words=None,title=None):
    
    embed_, w2, _= get_embedd(w2_, emb_, n_m, nouns[:num_words])
    print(len(w2))
    i2w = {}
    for key, val in w2.items():
        i2w[val]=key

    vis_data = tsne_viz(embed_)

    plt.scatter(vis_data[:, 0], vis_data[:, 1])

    i=0
    for x, y in zip( vis_data[:, 0], vis_data[:, 1]):
        plt.annotate(i2w[i], xy=(x, y), xytext=(0, 0), textcoords='offset points')
        i+=1
    plt.grid(True)    
    plt.title(title)    
    plt.show()
    plt.close()

# %%
# Perform visualization for different embedding type
w2ind_2, embedding_2, norm_m_2 = load_model('bow2.words')
get_viz(w2ind_2, embedding_2, norm_m_2, nouns,500,"tsne for bow2 ")
del embedding_2
del w2ind_2
# Out:
# loading Word-embeddings
# done!!
# 500
# Performing t-SNE
# 	... done

# %%
w2ind_5, embedding_5, norm_m_5 = load_model('bow5.words')
get_viz(w2ind_5, embedding_5, norm_m_5, nouns,500,"tsne for bow5 embeddings ")
del w2ind_5
del embedding_5
# Out:
# loading Word-embeddings
# done!!
# 499
# Performing t-SNE
# 	... done

# %%
w2ind_d, embedding_d, norm_m_d = load_model('deps.words')
get_viz(w2ind_d, embedding_d, norm_m_d, nouns,500,"tsne for dependency embeddings ")
del w2ind_d
del embedding_d
# Out:
# loading Word-embeddings
# done!!
# 499
# Performing t-SNE
# 	... done

# %% [markdown]
# ** Clustering Nouns **

# %%
from sklearn.cluster import KMeans
from sklearn.externals import joblib
from sklearn.manifold import MDS
from matplotlib.pyplot import cm 
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.palettes import d3,Plasma256, Viridis256
from sklearn import metrics
from bokeh.io import output_notebook
output_notebook()
plt.rcParams["figure.figsize"] = (20, 20)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9452e9f3-156a-4435-a31e-b884a7c11357">Loading BokehJS ...</span>
#     </div>

# %%
#find best clusters for each of the word embeddings
def get_best(w2_, emb_, n_m, nouns,clust=None,model=None):
    print()
    print("-------",model,"----------")
    print()
    embed_, w2, _= get_embedd(w2_, emb_, n_m, nouns)
    i2w = {}
    for key, val in w2.items():
        i2w[val]=key
    word_dict = {}    
    best_model = 0
    score =0 
    #Perform Clustering
    for num_clusters in clust:
        print("Trying Cluster of size {}".format(num_clusters))
        km = KMeans(n_clusters=num_clusters,n_init=20, random_state=42, max_iter=1000, n_jobs=-1)
        km.fit(embed_)
        clusters = km.labels_
        temp = metrics.silhouette_score(embed_, clusters)
        
        
        if temp > score:
            num_cls = num_clusters
            score = temp
            best_model = km
    
    print()
    print("Best score: ", score, "\nBest model: ", best_model, "\nnum of clusters", num_cls)
    
    print()
    
    for i,item in enumerate(embed_):
        if clusters[i] not in word_dict.keys():
            word_dict[clusters[i]] = []
        value = word_dict[clusters[i]]
        value.append(i2w[i])
        word_dict[clusters[i]] = value
        
    return embed_, best_model, num_cls, word_dict

def get_clusters(embed_, num_clusters, nouns,title=None):
    emb_tsne = tsne_viz(embed_)
    p = figure(tools="pan,wheel_zoom,reset,save",
               toolbar_location="above",
               title="T-SNE for most common words",plot_width=1000, plot_height=800)
    
    # Set colormap as a list
#     colormap = d3['Category20'][num_clusters]
#     colors = [colormap[i] for i in clusters]
    colors = [Viridis256[int(i)] for i in np.linspace(0,255, num_clusters)]

    source = ColumnDataSource(data=dict(x1=emb_tsne[:,0],
                                        x2=emb_tsne[:,1],
                                        names=nouns,
                                        colors=colors))

    p.scatter(x="x1", y="x2", size=5, source=source, color='colors')

    labels = LabelSet(x="x1", y="x2", text="names", y_offset=2,
                      text_font_size="8pt", text_color="#555555",
                      source=source,text_align='center')
    p.add_layout(labels)

    show(p)

# %%
w2ind_2, embedding_2, norm_m_2 = load_model('bow2.words')
embed_, model, num_clusters2, word_dict1 = get_best(w2ind_2, embedding_2, norm_m_2, nouns,[5,15,20,25,30,40,50, 60], "BoW2 embeddings")
# Out:
# loading Word-embeddings
# done!!
#
# ------- BoW2 embeddings ----------
#
# Trying Cluster of size 5
# Trying Cluster of size 15
# Trying Cluster of size 20
# Trying Cluster of size 25
# Trying Cluster of size 30
# Trying Cluster of size 40
# Trying Cluster of size 50
# Trying Cluster of size 60
#
# Best score:  0.027943709178643514
# Best model:  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#     n_clusters=50, n_init=20, n_jobs=-1, precompute_distances='auto',
#     random_state=42, tol=0.0001, verbose=0)
# num of clusters 50

# %%
get_clusters(embed_,num_clusters2,nouns,"tsne for bow2 ")
del embedding_2
del w2ind_2
# Out:
# Performing t-SNE
# 	... done
# C:\Users\Druv\Anaconda3\envs\NLP\lib\site-packages\bokeh\models\sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('colors', 60), ('names', 1996), ('x1', 1995), ('x2', 1995)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="40eb2b92-cbca-4790-b06c-55ae9608abcd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("40eb2b92-cbca-4790-b06c-55ae9608abcd");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("40eb2b92-cbca-4790-b06c-55ae9608abcd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '40eb2b92-cbca-4790-b06c-55ae9608abcd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7ea7034a-fd4a-4e06-89db-8f70cc0afadd":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1fd9d38d-739d-458e-b008-f0c7e869871c","type":"PanTool"},{"id":"ade6142f-fbe5-4452-81fb-e842699f7a50","type":"WheelZoomTool"},{"id":"80c5e9fb-c1be-4546-9c9f-b049f3359a4a","type":"ResetTool"},{"id":"568bc99a-ed1b-41de-bc85-1010e453a813","type":"SaveTool"}]},"id":"e0597c99-cebd-480d-b976-1dfed31789d5","type":"Toolbar"},{"attributes":{},"id":"0327dc20-d994-4ad4-9020-51c97d3de4a5","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"0327dc20-d994-4ad4-9020-51c97d3de4a5","type":"BasicTickFormatter"},"plot":{"id":"d27d7b1a-017e-4045-99a8-7e0ba794eaa6","subtype":"Figure","type":"Plot"},"ticker":{"id":"e1a952c0-752a-4a36-a349-c73ef1a00718","type":"BasicTicker"}},"id":"9d7affb5-061b-4209-8007-9d3c25f0e8b3","type":"LinearAxis"},{"attributes":{},"id":"ade6142f-fbe5-4452-81fb-e842699f7a50","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"2762ded9-2dbf-45bd-9cee-078f417a4023","type":"BasicTickFormatter"},"plot":{"id":"d27d7b1a-017e-4045-99a8-7e0ba794eaa6","subtype":"Figure","type":"Plot"},"ticker":{"id":"8d619a51-c14b-4c77-ac68-c023155e7451","type":"BasicTicker"}},"id":"42e611d4-32a2-4e88-86d3-791264074678","type":"LinearAxis"},{"attributes":{},"id":"2762ded9-2dbf-45bd-9cee-078f417a4023","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d27d7b1a-017e-4045-99a8-7e0ba794eaa6","subtype":"Figure","type":"Plot"},"source":{"id":"968c1fda-e28a-492f-a74e-02524a5e59c2","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":2}},"id":"585d4b27-b9ff-4711-b2d4-9c5a9cd9c866","type":"LabelSet"},{"attributes":{},"id":"e1a952c0-752a-4a36-a349-c73ef1a00718","type":"BasicTicker"},{"attributes":{"source":{"id":"968c1fda-e28a-492f-a74e-02524a5e59c2","type":"ColumnDataSource"}},"id":"902a0779-cb2b-47c6-bdd2-9f5a57efda07","type":"CDSView"},{"attributes":{"dimension":1,"plot":{"id":"d27d7b1a-017e-4045-99a8-7e0ba794eaa6","subtype":"Figure","type":"Plot"},"ticker":{"id":"e1a952c0-752a-4a36-a349-c73ef1a00718","type":"BasicTicker"}},"id":"3ddab89e-0cd4-45bd-83f4-2a606a996146","type":"Grid"},{"attributes":{"callback":null,"column_names":["x1","x2","names","colors"],"data":{"colors":["#440154","#45065A","#460C5F","#471265","#48196B","#481E70","#482374","#472A79","#462F7C","#45347F","#433A83","#423E85","#404387","#3E4989","#3C4D8A","#3A528B","#38578C","#365B8C","#345F8D","#31648D","#30688D","#2E6C8E","#2C718E","#2A758E","#29798E","#277D8E","#26818E","#24858D","#22898D","#218D8C","#20918C","#1F958B","#1E998A","#1E9D88","#1FA187","#21A685","#23A982","#27AD80","#2CB17D","#32B57A","#38B976","#40BD72","#47C06E","#4FC369","#59C764","#62CA5F","#6BCD59","#77D052","#81D34C","#8BD546","#97D83E","#A2DA37","#ADDC30","#BADE27","#C5DF21","#CFE11C","#DCE218","#E7E419","#F1E51C","#FDE724"],"names":["tournament","tactic","trousers","exhibition","screen","setting","nature","brush","bread","cell","vendor","fact","luke","carriage","constitution","contradiction","inspector","concentration","task","shareholder","chemical","ritual","infection","tower","loyalty","continent","load","priest","artist","growth","lack","ford","sound","suicide","office","directive","french","drama","cloud","sense","rope","conference","establishment","sheep","smoke","regulation","trip","character","ingredient","album","flood","complexity","apartment","engine","female","challenge","curriculum","settlement","tension","applicant","popularity","coach","decade","furniture","lucy","boat","traveller","roll","appeal","community","forest","fault","weather","door","material","intensity","mountain","cancer","honour","lock","clash","glory","rule","investigation","harry","alliance","partnership","publisher","layer","guidance","championship","owner","teenage ...

# %%
w2ind_5, embedding_5, norm_m_5 = load_model('bow5.words')
embed_, model, num_clusters5,word_dict2 = get_best(w2ind_5, embedding_5, norm_m_5, nouns,[5,15,20,25,30,40,50, 60], "BoW5 embeddings")
# Out:
# loading Word-embeddings
# done!!
#
# ------- BoW5 embeddings ----------
#
# Trying Cluster of size 5
# Trying Cluster of size 15
# Trying Cluster of size 20
# Trying Cluster of size 25
# Trying Cluster of size 30
# Trying Cluster of size 40
# Trying Cluster of size 50
# Trying Cluster of size 60
#
# Best score:  0.03596993213006383
# Best model:  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#     n_clusters=30, n_init=20, n_jobs=-1, precompute_distances='auto',
#     random_state=42, tol=0.0001, verbose=0)
# num of clusters 30

# %%
get_clusters(embed_,num_clusters5,nouns,"tsne for bow5 ")
del embedding_5
del w2ind_5
# Out:
# Performing t-SNE
# 	... done
# C:\Users\Druv\Anaconda3\envs\NLP\lib\site-packages\bokeh\models\sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('colors', 60), ('names', 1996), ('x1', 1995), ('x2', 1995)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="50ab18c8-2f6e-42af-b331-8d5afb9c417a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("50ab18c8-2f6e-42af-b331-8d5afb9c417a");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("50ab18c8-2f6e-42af-b331-8d5afb9c417a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '50ab18c8-2f6e-42af-b331-8d5afb9c417a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f95c73c9-54ee-4c18-8838-808cfaa1da08":{"roots":{"references":[{"attributes":{},"id":"564d69aa-7367-4865-a2ad-9049007ec0a6","type":"PanTool"},{"attributes":{"callback":null},"id":"cc8329c7-701b-4935-b548-e031b54b60a7","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x1","x2","names","colors"],"data":{"colors":["#440154","#45065A","#460C5F","#471265","#48196B","#481E70","#482374","#472A79","#462F7C","#45347F","#433A83","#423E85","#404387","#3E4989","#3C4D8A","#3A528B","#38578C","#365B8C","#345F8D","#31648D","#30688D","#2E6C8E","#2C718E","#2A758E","#29798E","#277D8E","#26818E","#24858D","#22898D","#218D8C","#20918C","#1F958B","#1E998A","#1E9D88","#1FA187","#21A685","#23A982","#27AD80","#2CB17D","#32B57A","#38B976","#40BD72","#47C06E","#4FC369","#59C764","#62CA5F","#6BCD59","#77D052","#81D34C","#8BD546","#97D83E","#A2DA37","#ADDC30","#BADE27","#C5DF21","#CFE11C","#DCE218","#E7E419","#F1E51C","#FDE724"],"names":["tournament","tactic","trousers","exhibition","screen","setting","nature","brush","bread","cell","vendor","fact","luke","carriage","constitution","contradiction","inspector","concentration","task","shareholder","chemical","ritual","infection","tower","loyalty","continent","load","priest","artist","growth","lack","ford","sound","suicide","office","directive","french","drama","cloud","sense","rope","conference","establishment","sheep","smoke","regulation","trip","character","ingredient","album","flood","complexity","apartment","engine","female","challenge","curriculum","settlement","tension","applicant","popularity","coach","decade","furniture","lucy","boat","traveller","roll","appeal","community","forest","fault","weather","door","material","intensity","mountain","cancer","honour","lock","clash","glory","rule","investigation","harry","alliance","partnership","publisher","layer","guidance","championship","owner","teenager","lecture","state","visit","wealth","constraint","ireland","agenda","pillow","interpretation","model","handle","equipment","rabbit","impression","promise","accuracy","programme","breakfast","network","army","determination","sample","spell","research","silence","trap","brow","south","maximum","trustee","group","barrier","transport","mile","lifetime","beginning","season","human","reward","noise","defence","planet","walker","faction","replacement","scene","condition","specimen","moscow","downstairs","hill","heart","licence","buyer","text","pair","blade","farmer","advantage","cross","paper","treaty","weakness","question","poet","violence","cottage","mixture","assessment","shoe","percentage","rate","ladder","jackson","explosion","process","stephen","place","bedroom","harm","warning","congress","judge","robert","jack","count","port","american","german","paris","tendency","husband","protein","appearance","account","receipt","formula","channel","attempt","collar","compound","executive","injunction","plane","bottle","corporation","birth","volume","help","solicitor","addition","firm","relation","crop","balance","lane","remark","basket","race","front","reduction","brain","occasion","newspaper","kelly","voice","sugar","headquarters","charity","warrant","event","aspect","youth","summit","being","trial","anxiety","island","consideration","outcome","proceedings","maker","grade","practice","wales","part","view","train","fear","punishment","song","drop","rebel","weight","coffee","service","stimulus","revolution","status","sensation","cheque","breach","angle","tribunal","murder","cliff","tool","extension","attraction","club","admission","ideal","manager","pilot","palace","argument","order","depth","tissue","purchaser","counter","design","constable","kind","document","benefit","path","issue","servant","moment","announcement","frustration","goods","life","flight","glance","imagination","support","let","victim","exposure","politics","context","quality","requirement","range","innovation","consent","advertising","capability","operation","links","benjamin","average","fortune","host ...

# %%
w2ind_d, embedding_d, norm_m_d = load_model('deps.words')
embed_, model, num_clustersd,word_dict3 = get_best(w2ind_d, embedding_d, norm_m_d, nouns,[5,15,20,25,30,40,50, 60], "Dependency embeddings")
# Out:
# loading Word-embeddings
# done!!
#
# ------- Dependency embeddings ----------
#
# Trying Cluster of size 5
# Trying Cluster of size 15
# Trying Cluster of size 20
# Trying Cluster of size 25
# Trying Cluster of size 30
# Trying Cluster of size 40
# Trying Cluster of size 50
# Trying Cluster of size 60
#
# Best score:  0.032178014503622655
# Best model:  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#     n_clusters=40, n_init=20, n_jobs=-1, precompute_distances='auto',
#     random_state=42, tol=0.0001, verbose=0)
# num of clusters 40

# %%
get_clusters(embed_,num_clustersd,nouns,"tsne for deps ")
del w2ind_d
del embedding_d
# Out:
# Performing t-SNE
# 	... done
# C:\Users\Druv\Anaconda3\envs\NLP\lib\site-packages\bokeh\models\sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('colors', 60), ('names', 1996), ('x1', 1995), ('x2', 1995)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c6aa89d8-1cb3-4eee-ae43-34eca602e332"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("c6aa89d8-1cb3-4eee-ae43-34eca602e332");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c6aa89d8-1cb3-4eee-ae43-34eca602e332");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c6aa89d8-1cb3-4eee-ae43-34eca602e332' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f5496df3-69ac-4b47-ad96-12335417f079":{"roots":{"references":[{"attributes":{},"id":"ee13357d-42e9-4cd4-b542-1ac7721f0d54","type":"BasicTicker"},{"attributes":{"fill_color":{"field":"colors"},"line_color":{"field":"colors"},"size":{"units":"screen","value":5},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"8607d707-6719-4539-990f-c2d502aaadb7","type":"Circle"},{"attributes":{},"id":"77dadbe7-e178-4e77-8ff5-702017b43755","type":"BasicTickFormatter"},{"attributes":{},"id":"b650ed80-f77c-4f9e-89c3-8218f96048cf","type":"BasicTicker"},{"attributes":{},"id":"3c32caaf-2f62-43e5-aa75-2921c4fb7fc6","type":"LinearScale"},{"attributes":{"below":[{"id":"834bf3b5-d146-4a1c-8493-3564204b81ff","type":"LinearAxis"}],"left":[{"id":"3f8303c2-ebcd-4202-8b49-dc873193e5ff","type":"LinearAxis"}],"plot_height":800,"plot_width":1000,"renderers":[{"id":"834bf3b5-d146-4a1c-8493-3564204b81ff","type":"LinearAxis"},{"id":"0bfb32d4-425a-4e28-a048-725fe5186956","type":"Grid"},{"id":"3f8303c2-ebcd-4202-8b49-dc873193e5ff","type":"LinearAxis"},{"id":"ea393370-0abc-40ae-b6ed-85c5944a3557","type":"Grid"},{"id":"33d2e0ae-6ed7-4813-903a-1b51d7980952","type":"GlyphRenderer"},{"id":"242b41f5-bdae-409a-bba4-78e68b7e893a","type":"LabelSet"}],"title":{"id":"93094ee3-b1c6-46c0-a3d8-9c5254afe9b8","type":"Title"},"toolbar":{"id":"063f4123-d8df-413d-9acb-deedfa816944","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"6bae7e4c-64a9-46bc-aba5-b538782d97eb","type":"DataRange1d"},"x_scale":{"id":"3c32caaf-2f62-43e5-aa75-2921c4fb7fc6","type":"LinearScale"},"y_range":{"id":"f841d472-685d-446c-b603-1310c1338cf7","type":"DataRange1d"},"y_scale":{"id":"1f99b65c-a7bc-4296-81f3-2ed27facd7f6","type":"LinearScale"}},"id":"97d1b38b-1d35-4b5a-99c4-3c0f3e150cd0","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"6bae7e4c-64a9-46bc-aba5-b538782d97eb","type":"DataRange1d"},{"attributes":{"formatter":{"id":"77dadbe7-e178-4e77-8ff5-702017b43755","type":"BasicTickFormatter"},"plot":{"id":"97d1b38b-1d35-4b5a-99c4-3c0f3e150cd0","subtype":"Figure","type":"Plot"},"ticker":{"id":"ee13357d-42e9-4cd4-b542-1ac7721f0d54","type":"BasicTicker"}},"id":"834bf3b5-d146-4a1c-8493-3564204b81ff","type":"LinearAxis"},{"attributes":{},"id":"2ccfd677-62cb-4b67-b1e4-0a109e50df44","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"97d1b38b-1d35-4b5a-99c4-3c0f3e150cd0","subtype":"Figure","type":"Plot"},"ticker":{"id":"b650ed80-f77c-4f9e-89c3-8218f96048cf","type":"BasicTicker"}},"id":"ea393370-0abc-40ae-b6ed-85c5944a3557","type":"Grid"},{"attributes":{},"id":"aaf28005-1f56-40c8-bb7b-bf7b7d943086","type":"PanTool"},{"attributes":{},"id":"979252c2-7d82-4f8b-96a6-6c17f3516062","type":"WheelZoomTool"},{"attributes":{},"id":"b4ccb84d-48db-490c-894f-8b632f12fe53","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x1","x2","names","colors"],"data":{"colors":["#440154","#45065A","#460C5F","#471265","#48196B","#481E70","#482374","#472A79","#462F7C","#45347F","#433A83","#423E85","#404387","#3E4989","#3C4D8A","#3A528B","#38578C","#365B8C","#345F8D","#31648D","#30688D","#2E6C8E","#2C718E","#2A758E","#29798E","#277D8E","#26818E","#24858D","#22898D","#218D8C","#20918C","#1F958B","#1E998A","#1E9D88","#1FA187","#21A685","#23A982","#27AD80","#2CB17D","#32B57A","#38B976","#40BD72","#47C06E","#4FC369","#59C764","#62CA5F","#6BCD59","#77D052","#81D34C","#8BD546","#97D83E","#A2DA37","#ADDC30","#BADE27","#C5DF21","#CFE11C","#DCE218","#E7E419","#F1E51C","#FDE724"],"names":["tournament","tactic","trousers","exhibition","screen","setting","nature","brush","bread","cell","vendor","fact","luke","carriage","constitution","contradiction","inspector","concentration","task","shareholder","chemical","ritual","infection","tower","loyalty","continent","load","priest","artist","growth","lack","ford","sound","suicide","office","directive","french","drama","cloud","sense","rope","conference","establishment","sheep","smoke","regulation","trip","character","ing ...

# %%
print("Random samples from BOW2")
for i in range(num_clusters2):
    print(word_dict1[i])
    print("*******************************************")
# Out:
# Random samples from BOW2
# ['duke', 'lord', 'count', 'king', 'emperor', 'queen', 'knight', 'earl', 'princess', 'lady', 'prince']
# *******************************************
# ['uncertainty', 'respect', 'fear', 'hostility', 'curiosity', 'burden', 'surprise', 'caution', 'favour', 'difficulty', 'attention', 'pride', 'sympathy', 'satisfaction', 'embarrassment', 'excitement', 'disappointment', 'danger', 'frustration', 'responsibility', 'enthusiasm', 'pleasure', 'doubt', 'expectation', 'confusion', 'contempt', 'hope', 'interest', 'confidence', 'bias', 'concern', 'guilt', 'trouble', 'suspicion', 'delight', 'anger']
# *******************************************
# ['wound', 'cancer', 'gene', 'stroke', 'hair', 'heart', 'corpse', 'body', 'tongue', 'brain', 'skin', 'surgery', 'vein', 'limb', 'tooth', 'blood', 'spine', 'leaf', 'bone', 'stomach', 'muscle', 'tissue', 'throat', 'cell', 'root', 'breast', 'stem', 'nerve']
# *******************************************
# ['importance', 'achievement', 'lifetime', 'goal', 'improvement', 'participation', 'award', 'progress', 'contribution', 'prospect', 'priority', 'success', 'role', 'popularity', 'status', 'medal', 'advantage', 'career', 'entry', 'prize', 'worth', 'impact', 'prospects', 'future', 'performance', 'best', 'honour', 'work', 'reputation', 'merit', 'coverage', 'promotion', 'talent', 'benefit', 'influence', 'life']
# *******************************************
# ['position', 'gesture', 'prayer', 'ideology', 'ritual', 'curriculum', 'activity', 'field', 'tradition', 'movement', 'skill', 'virtue', 'behaviour', 'discipline', 'identity', 'leadership', 'strategy', 'practice', 'agenda', 'exercise', 'tactic', 'belief', 'logic', 'attitude', 'pursuit', 'conduct', 'stance', 'course', 'lesson', 'hierarchy', 'faith', 'doctrine', 'spirit', 'profession']
# *******************************************
# ['team', 'football', 'coach', 'player', 'captain', 'league', 'manager', 'defender', 'receiver', 'champion']
# *******************************************
# ['finding', 'account', 'interpretation', 'detail', 'momentum', 'knowledge', 'background', 'norm', 'basis', 'insight', 'image', 'grounds', 'meaning', 'principle', 'sense', 'evolution', 'subject', 'thinking', 'dimension', 'shape', 'outline', 'emphasis', 'spectrum', 'expression', 'material', 'situation', 'origin', 'atmosphere', 'view', 'category', 'context', 'perspective', 'entity', 'thought', 'setting', 'balance', 'sphere', 'figure', 'information', 'ideal', 'sort', 'awareness', 'concept', 'direction', 'phrase', 'focus', 'experience', 'objective', 'aspect', 'glimpse', 'effect', 'jesus', 'reality', 'manner', 'whole', 'kind', 'validity', 'notion', 'phenomenon', 'truth', 'understanding', 'circumstance', 'necessity', 'description', 'nature', 'contents', 'name', 'definition', 'idea', 'purpose', 'significance', 'source', 'outcome', 'scope', 'environment', 'means', 'moment']
# *******************************************
# ['volunteer', 'police', 'defence', 'warrant', 'mission', 'raid', 'security', 'fleet', 'rebel', 'union', 'youth', 'reserve', 'resistance', 'enemy', 'fire', 'headquarters', 'guard', 'troops', 'duty', 'assault', 'prison', 'personnel', 'killing', 'gang', 'squad', 'task', 'expedition', 'staff', 'secret', 'crew', 'refugee', 'force', 'intelligence', 'command', 'army', 'base']
# *******************************************
# ['patrick', 'robert', 'eliot', 'francis', 'richard', 'martin', 'tony', 'luke', 'mark', 'bill', 'philip', 'joseph', 'benjamin', 'nigel', 'charles', 'george', 'david', 'henry', 'mungo', 'adam', 'paul', 'stephen', 'michael', 'edward', 'john', 'peter', 'william', 'athelstan', 'james', 'jack', 'simon', 'thomas', 'harry']
# *******************************************
# ['electricity', 'fuel', 'beer', 'sugar', 'drug', 'acid', 'chemical', 'salt', 'water', 'seed', 'meat', 'food', 'crop', 'waste', 'juice', 'coffee', 'potato', 'diet', 'coal', 'drink', 'grain', 'energy', 'fruit', 'alcohol', 'bulk', 'heat', 'wine', 'substance', 'bread', 'milk']
# *******************************************
# ['incidence', 'length', 'quantity', 'accuracy', 'rating', 'size', 'speed', 'average', 'profile', 'height', 'extent', 'cost', 'register', 'sensitivity', 'value', 'volume', 'limit', 'proportion', 'availability', 'minimum', 'amount', 'level', 'share', 'relative', 'effectiveness', 'output', 'ratio', 'complexity', 'rate', 'total', 'load', 'angle', 'depths', 'lifespan', 'price', 'equivalent', 'degree', 'pace', 'scale', 'population', 'concentration', 'peak', 'efficiency', 'increase', 'margin', 'quality', 'frequency', 'dose', 'range', 'excess', 'rank', 'strength', 'weight', 'temperature', 'depth', 'class', 'score', 'mass', 'number', 'capacity', 'maximum', 'target', 'distance', 'percentage', 'ease', 'intensity']
# *******************************************
# ['australia', 'america', 'italy', 'leeds', 'india', 'germany', 'paris', 'britain', 'israel', 'england', 'york', 'wales', 'london', 'rome', 'oxford', 'ireland', 'russia', 'scotland', 'liverpool', 'china', 'japan', 'europe', 'spain', 'kong', 'iraq', 'france', 'africa', 'moscow']
# *******************************************
# ['client', 'defendant', 'person', 'holder', 'participant', 'investor', 'plaintiff', 'offender', 'seller', 'customer', 'owner', 'tenant', 'buyer', 'shareholder', 'employee', 'voter', 'employer', 'competitor', 'creditor', 'landlord', 'driver', 'parent', 'victim', 'witness', 'purchaser', 'applicant', 'patient']
# *******************************************
# ['review', 'negotiation', 'dispute', 'consideration', 'article', 'controversy', 'explanation', 'discourse', 'dialogue', 'criticism', 'talk', 'paragraph', 'list', 'user', 'question', 'stuff', 'thread', 'poll', 'essay', 'matter', 'issue', 'consensus', 'conflict', 'compromise', 'topic', 'debate', 'conversation', 'page', 'content', 'discussion', 'guideline']
# *******************************************
# ['service', 'routine', 'statistics', 'major', 'professional', 'assessment', 'safety', 'assistance', 'study', 'grade', 'preparation', 'expertise', 'development', 'treatment', 'health', 'protection', 'resource', 'test', 'support', 'control', 'examination', 'consultation', 'relief', 'certificate', 'instruction', 'management', 'guidance', 'research', 'specialist', 'training', 'inspection', 'maintenance', 'search', 'evaluation', 'teaching', 'demonstration', 'observation', 'planning', 'compliance', 'education', 'survival', 'joint', 'care', 'survey']
# *******************************************
# ['problem', 'explosion', 'disaster', 'delay', 'disease', 'factor', 'damage', 'illness', 'symptom', 'mistake', 'infection', 'breach', 'fault', 'damages', 'incident', 'shock', 'error', 'failure', 'disorder', 'cause', 'abuse', 'result', 'threat', 'harm', 'accident', 'loss', 'weakness', 'suicide', 'change', 'defect', 'consequence', 'injury', 'reaction', 'condition', 'crash', 'strain', 'panic', 'barrier', 'risk']
# *******************************************
# ['lunch', 'downstairs', 'shelter', 'dinner', 'accommodation', 'housing', 'meal', 'cupboard', 'room', 'studio', 'hotel', 'bedroom', 'breakfast', 'tent', 'shop', 'kitchen', 'cottage', 'garden', 'store', 'garage', 'apartment', 'home', 'theatre', 'bathroom', 'farm', 'restaurant']
# *******************************************
# ['photographer', 'scientist', 'researcher', 'author', 'collector', 'writer', 'practitioner', 'consultant', 'designer', 'lawyer', 'architect', 'editor', 'politician', 'historian', 'agent', 'traveller', 'maker', 'artist', 'dealer', 'expert', 'critic', 'reporter', 'accountant', 'actor', 'producer', 'developer', 'engineer', 'poet', 'publisher', 'journalist', 'scholar', 'commentator', 'dancer', 'analyst']
# *******************************************
# ['estimate', 'instance', 'mechanism', 'composition', 'measure', 'experiment', 'function', 'model', 'pattern', 'interval', 'method', 'procedure', 'formula', 'index', 'measurement', 'hypothesis', 'process', 'approach', 'datum', 'solution', 'theory', 'constraint', 'arrangement', 'term', 'equation', 'technique', 'structure', 'variable', 'instrument', 'analysis', 'example', 'questionnaire', 'parameter', 'cycle', 'criterion', 'calculation', 'curve', 'framework']
# *******************************************
# ['clinton', 'scott', 'wilson', 'johnson', 'clarke', 'thatcher', 'kelly', 'cook', 'ford', 'lewis', 'willie', 'scot', 'williams', 'washington', 'baker', 'miller', 'graham', 'morgan', 'corbett', 'bush', 'wright', 'brown', 'jones', 'walker', 'smith', 'howard', 'jackson', 'taylor']
# *******************************************
# ['coin', 'deposit', 'territory', 'liability', 'crown', 'rent', 'ticket', 'lease', 'transaction', 'dollar', 'licence', 'loan', 'contract', 'stake', 'venture', 'land', 'settlement', 'property', 'holding', 'purchase', 'succession', 'possession', 'gift', 'bank', 'ownership', 'cheque', 'trading', 'receipt', 'monopoly', 'stock', 'concession', 'currency', 'trade', 'membership', 'mortgage', 'sale', 'payment', 'grant']
# *******************************************
# ['prisoner', 'citizen', 'living', 'gentleman', 'farmer', 'killer', 'teacher', 'policeman', 'student', 'priest', 'doctor', 'soldier', 'child', 'detective', 'youngster', 'worker', 'peasant', 'inhabitant', 'rider', 'nurse', 'resident', 'master', 'miner', 'girl', 'servant', 'woman', 'pupil', 'teenager', 'thief']
# *******************************************
# ['collar', 'thigh', 'brow', 'corner', 'shoulder', 'left', 'sleeve', 'hand', 'chest', 'side', 'forehead', 'cheek', 'fist', 'mouth', 'front', 'eyebrow', 'bottom', 'neck', 'right', 'head', 'waist', 'tail', 'elbow', 'thumb', 'ankle', 'chin', 'wrist', 'foot', 'face', 'back', 'wing', 'finger', 'knee', 'heel', 'nose']
# *******************************************
# ['growth', 'flow', 'violence', 'turnover', 'traffic', 'current', 'crime', 'crisis', 'inequality', 'shortage', 'emission', 'boom', 'exposure', 'deficit', 'depression', 'decline', 'recession', 'consumption', 'pollution', 'tension', 'climate', 'pressure', 'economy', 'trend', 'stress', 'poverty', 'reduction', 'discrimination', 'flood', 'inflation', 'stability', 'stimulus', 'demand', 'unemployment']
# *******************************************
# ['estate', 'town', 'temple', 'village', 'gate', 'grave', 'chapel', 'complex', 'summit', 'chamber', 'hill', 'site', 'castle', 'statue', 'christ', 'villa', 'colony', 'entrance', 'park', 'house', 'terrace', 'cathedral', 'tower', 'church', 'mill', 'square', 'building', 'camp', 'city', 'hall', 'acre', 'station', 'palace']
# *******************************************
# ['mist', 'rose', 'wind', 'darkness', 'continent', 'ocean', 'wave', 'planet', 'glory', 'stranger', 'band', 'shadow', 'earth', 'breeze', 'rain', 'tide', 'sunlight', 'moon', 'snow', 'z', 'horizon', 'weather', 'flame', 'dust', 'monster', 'storm', 'waters', 'dawn', 'light', 'torch', 'hell', 'heaven', 'chaos', 'cloud', 'angel', 'star']
# *******************************************
# ['conservative', 'parliament', 'democrat', 'referendum', 'tory', 'ward', 'labour', 'councillor', 'seat', 'election', 'candidate', 'party', 'kinnock', 'constituency']
# *******************************************
# ['module', 'system', 'option', 'scheme', 'code', 'unit', 'protocol', 'platform', 'file', 'engine', 'database', 'alternative', 'project', 'standard', 'space', 'capability', 'format', 'channel', 'processor', 'facility', 'specification', 'software', 'mode', 'network', 'device', 'core', 'tool', 'interface', 'application', 'programme', 'program', 'computer', 'package']
# *******************************************
# ['card', 'disc', 'handle', 'clock', 'slice', 'plate', 'tray', 'frame', 'lamp', 'window', 'cover', 'envelope', 'slide', 'forward', 'pack', 'screen', 'switch', 'desk', 'custom', 'tape', 'disk', 'panel', 'patch', 'packet', 'pile', 'pocket', 'column', 'table', 'shelf', 'button', 'chart', 'menu', 'pool', 'heap', 'block', 'chip', 'bucket', 'camera', 'leaflet', 'filter', 'door', 'flat', 'lock', 'container', 'deck', 'battery', 'boot', 'sheet', 'machine', 'mirror', 'display', 'shell', 'dish']
# *******************************************
# ['diana', 'alice', 'kate', 'rachel', 'elizabeth', 'penny', 'anne', 'robyn', 'sarah', 'isabel', 'laura', 'ruth', 'caroline', 'maggie', 'marie', 'emily', 'anna', 'charlie', 'mary', 'jane', 'lily', 'blanche', 'lucy', 'helen', 'susan']
# *******************************************
# ['match', 'trophy', 'contest', 'quarter', 'obstacle', 'bowl', 'circuit', 'rally', 'winner', 'event', 'challenge', 'festival', 'second', 'competition', 'tour', 'round', 'title', 'victory', 'game', 'triumph', 'final', 'championship', 'tournament', 'qualification', 'open', 'world', 'race', 'exhibition', 'sport']
# *******************************************
# ['laugh', 'spread', 'sensation', 'colour', 'beauty', 'look', 'habit', 'breath', 'hint', 'plenty', 'present', 'sweat', 'sound', 'appearance', 'smoke', 'touch', 'flesh', 'scent', 'sight', 'smell', 'flavour', 'noise', 'taste']
# *******************************************
# ['universe', 'ghost', 'diary', 'scene', 'film', 'marx', 'novel', 'song', 'movie', 'television', 'book', 'plot', 'dream', 'joke', 'character', 'hero', 'horror', 'cast', 'drama', 'recording', 'portrait', 'headline', 'painting', 'drawing', 'album', 'video', 'strip', 'series', 'verse', 'tune', 'poem', 'episode', 'poster', 'photograph', 'feature', 'picture', 'mystery', 'dance', 'tragedy', 'myth', 'theme', 'story', 'tale', 'chapter']
# *******************************************
# ['intention', 'discretion', 'tendency', 'ability', 'ambition', 'attempt', 'desire', 'chance', 'opportunity', 'preference', 'loyalty', 'wish', 'choice', 'determination', 'lack', 'will', 'effort', 'refusal', 'need', 'willingness', 'courage', 'obligation', 'potential', 'commitment', 'promise', 'incentive']
# *******************************************
# ['district', 'road', 'section', 'street', 'track', 'branch', 'region', 'location', 'mile', 'path', 'valley', 'border', 'ridge', 'line', 'circle', 'boundary', 'tunnel', 'lane', 'trail', 'port', 'route', 'point', 'river', 'canal', 'yard', 'bridge', 'railway', 'area', 'rail', 'corridor', 'stretch', 'airport', 'stream']
# *******************************************
# ['rabbit', 'horse', 'fish', 'other', 'flower', 'animal', 'insect', 'female', 'sheep', 'cattle', 'adult', 'creature', 'bird', 'plant', 'lamb', 'mouse', 'prey', 'human', 'organ', 'bull', 'male', 'individual', 'organism']
# *******************************************
# ['reward', 'subsidy', 'fortune', 'debt', 'spending', 'supplies', 'power', 'earnings', 'employment', 'fund', 'surplus', 'expenditure', 'income', 'pension', 'profit', 'goods', 'credit', 'finance', 'supply', 'money', 'portfolio', 'asset', 'budget', 'insurance', 'household', 'investment', 'capital', 'wages', 'savings', 'welfare', 'allowance', 'dividend', 'expense', 'compensation', 'wealth', 'salary', 'cash', 'revenue']
# *******************************************
# ['conception', 'transition', 'acceptance', 'separation', 'consent', 'freedom', 'allocation', 'selection', 'intervention', 'recovery', 'admission', 'transfer', 'implementation', 'independence', 'integration', 'isolation', 'transformation', 'adoption', 'conversion', 'marriage', 'presentation', 'birth', 'rejection', 'recognition', 'unity', 'identification', 'representation', 'approval']
# *******************************************
# ['order', 'limitation', 'penalty', 'proceedings', 'requirement', 'clause', 'statute', 'directive', 'jurisdiction', 'resolution', 'remedy', 'plan', 'convention', 'policy', 'authority', 'provision', 'declaration', 'legislation', 'constitution', 'sanction', 'privilege', 'regulation', 'rule', 'charter', 'reform', 'treaty', 'rights', 'injunction', 'draft', 'decree', 'amendment', 'restriction']
# *******************************************
# ['tribunal', 'treasury', 'republic', 'majority', 'empire', 'embassy', 'faction', 'revolution', 'assembly', 'official', 'cabinet', 'opposition', 'government', 'congress', 'pope', 'committee', 'prime', 'coalition', 'ministry', 'gorbachev', 'commission', 'state', 'minority', 'hitler', 'jury', 'justice', 'kingdom', 'peace', 'delegation', 'administration', 'politics', 'democracy', 'regime', 'province', 'council', 'court']
# *******************************************
# ['pound', 'stair', 'pole', 'bell', 'cable', 'needle', 'arrow', 'hole', 'wire', 'beam', 'hook', 'rope', 'stitch', 'sword', 'tree', 'stick', 'ball', 'crack', 'shaft', 'blade', 'bullet', 'metre', 'strand', 'metal', 'grip', 'ladder', 'gear', 'fibre', 'tube', 'knot', 'wheel', 'ring', 'belt', 'inch', 'chain', 'pulse', 'horn', 'string', 'pipe', 'barrel', 'guitar']
# *******************************************
# ['personality', 'sleep', 'tone', 'silence', 'self', 'passion', 'pain', 'impulse', 'instinct', 'warmth', 'mood', 'laughter', 'imagination', 'grin', 'vision', 'motion', 'perception', 'rhythm', 'feeling', 'emotion', 'terror', 'senses', 'love', 'reflection', 'anxiety', 'smile', 'consciousness', 'memory', 'rage', 'soul', 'happiness', 'mind', 'voice', 'gaze', 'comfort', 'sigh']
# *******************************************
# ['kiss', 'lead', 'lift', 'attack', 'move', 'gain', 'step', 'journey', 'fighting', 'ride', 'play', 'pass', 'blow', 'trip', 'draw', 'tear', 'roll', 'return', 'struggle', 'fight', 'action', 'hold', 'shot', 'defeat', 'stand', 'rise', 'trick', 'advance', 'turn', 'punch', 'kick', 'strike', 'shift', 'drop', 'campaign', 'walk', 'drive', 'hunt', 'battle', 'help', 'spell', 'stop', 'watch', 'clash', 'protest', 'trap', 'break', 'counter', 'let']
# *******************************************
# ['tonne', 'missile', 'craft', 'passenger', 'aircraft', 'motor', 'bike', 'bomb', 'ship', 'vessel', 'transport', 'carriage', 'weapon', 'boat', 'flight', 'tank', 'taxi', 'carrier', 'vehicle', 'mine', 'plane', 'train', 'lorry', 'whilst', 'airline', 'landing', 'while', 'pilot', 'helicopter', 'truck']
# *******************************************
# ['characteristic', 'collection', 'part', 'variety', 'symbol', 'compound', 'domain', 'being', 'fraction', 'particle', 'portion', 'trace', 'combination', 'item', 'array', 'object', 'sequence', 'pair', 'variation', 'catalogue', 'cluster', 'sample', 'form', 'mixture', 'bacterium', 'handful', 'copy', 'layer', 'medium', 'type', 'virus', 'molecule', 'protein', 'fragment', 'specimen', 'element', 'phase', 'species', 'piece', 'version', 'component', 'ingredient', 'couple', 'remains']
# *******************************************
# ['vote', 'report', 'invitation', 'thanks', 'signal', 'reception', 'offer', 'recommendation', 'petition', 'document', 'post', 'warning', 'phone', 'sign', 'answer', 'reference', 'message', 'record', 'comment', 'visit', 'request', 'note', 'letter', 'notice', 'advice', 'check', 'reply', 'address', 'input', 'call', 'quote', 'alarm', 'telephone', 'hearing', 'permission', 'response', 'glance']
# *******************************************
# ['white', 'paint', 'cake', 'garment', 'cloth', 'recipe', 'skirt', 'bath', 'fabric', 'brush', 'clothes', 'green', 'suit', 'cream', 'bottle', 'baby', 'carpet', 'basket', 'curtain', 'dress', 'mask', 'coffin', 'black', 'mess', 'trousers', 'knife', 'glass', 'pillow', 'signature', 'shirt', 'paper', 'palm', 'candle', 'gold', 'nail', 'sofa', 'uniform', 'jacket', 'blanket', 'furniture', 'glove', 'shoe', 'champagne', 'seal', 'pint', 'flag', 'cigarette', 'coat', 'towel']
# *******************************************
# ['season', 'past', 'times', 'occasion', 'concert', 'anniversary', 'thousand', 'million', 'century', 'meeting', 'hundred', 'guest', 'schedule', 'hour', 'show', 'month', 'night', 'week', 'year', 'afternoon', 'ceremony', 'birthday', 'minute', 'host', 'wicket', 'seconds', 'morning', 'place', 'holiday', 'date', 'edition', 'decade', 'session', 'period', 'half', 'time', 'stage', 'spot', 'weekend', 'evening']
# *******************************************
# ['subsidiary', 'equipment', 'vendor', 'sector', 'company', 'import', 'product', 'label', 'manufacturer', 'market', 'advertising', 'premium', 'apple', 'machinery', 'production', 'enterprise', 'brand', 'industry', 'operator', 'distribution', 'design', 'advertisement', 'export', 'supplier', 'innovation', 'factory', 'technology', 'generation', 'consumer', 'business']
# *******************************************
# ['insider', 'public', 'people', 'crowd', 'magazine', 'visitor', 'media', 'tourist', 'publicity', 'print', 'radio', 'observer', 'press', 'viewer', 'fashion', 'reader', 'news', 'guide', 'newspaper', 'reading', 'audience', 'mail']
# *******************************************

# %%
print("Random samples from BOW5")
for i in range(num_clusters5):
    print(word_dict2[i])
    print("*******************************************")
# Out:
# Random samples from BOW5
# ['beer', 'sugar', 'salt', 'cream', 'bottle', 'juice', 'coffee', 'potato', 'apple', 'drink', 'grain', 'fruit', 'alcohol', 'ingredient', 'champagne', 'wine', 'cigarette', 'milk', 'flavour']
# *******************************************
# ['addition', 'difference', 'comparison', 'relation', 'being', 'favour', 'distinction', 'combination', 'connection', 'relative', 'contact', 'relationship', 'contrast', 'handful', 'equivalent', 'manner', 'contradiction', 'representation', 'interaction', 'response']
# *******************************************
# ['conception', 'finding', 'interpretation', 'basis', 'meaning', 'principle', 'extent', 'sense', 'thinking', 'premise', 'proof', 'view', 'perspective', 'hypothesis', 'thought', 'approach', 'evidence', 'sort', 'tactic', 'concept', 'impression', 'theory', 'implication', 'objective', 'belief', 'logic', 'motive', 'compromise', 'expectation', 'kind', 'validity', 'notion', 'possibility', 'understanding', 'necessity', 'assumption', 'conclusion', 'doctrine', 'definition', 'idea', 'purpose', 'proposition', 'means']
# *******************************************
# ['clinton', 'eliot', 'bell', 'scott', 'wilson', 'johnson', 'clarke', 'thatcher', 'kelly', 'ward', 'cook', 'ford', 'lewis', 'williams', 'washington', 'baker', 'miller', 'lane', 'mungo', 'graham', 'morgan', 'hunt', 'corbett', 'bush', 'wright', 'brown', 'jones', 'walker', 'smith', 'howard', 'jackson', 'grant', 'taylor']
# *******************************************
# ['drug', 'death', 'violence', 'illness', 'crime', 'incident', 'killer', 'offender', 'arrest', 'abuse', 'punishment', 'accident', 'suicide', 'prison', 'killing', 'gang', 'offence', 'terror', 'affair', 'conviction', 'murder', 'scandal', 'victim', 'witness', 'trial', 'prosecution']
# *******************************************
# ['momentum', 'flow', 'signal', 'experiment', 'beam', 'spectrum', 'impulse', 'particle', 'wave', 'envelope', 'error', 'array', 'emission', 'output', 'measurement', 'sample', 'angle', 'medium', 'frequency', 'variable', 'light', 'filter', 'temperature', 'pulse', 'input', 'stimulus', 'calculation', 'curve', 'intensity', 'noise']
# *******************************************
# ['replacement', 'transition', 'establishment', 'completion', 'separation', 'existence', 'announcement', 'expansion', 'departure', 'withdrawal', 'resignation', 'formation', 'destruction', 'passage', 'succession', 'adoption', 'beginning', 'conversion', 'creation', 'merger', 'removal', 'arrival', 'release', 'retirement', 'rejection', 'acquisition', 'absence', 'discovery', 'closure', 'introduction']
# *******************************************
# ['volunteer', 'police', 'prisoner', 'citizen', 'person', 'gentleman', 'farmer', 'captain', 'bond', 'hero', 'participant', 'agent', 'traveller', 'supporter', 'policeman', 'student', 'priest', 'doctor', 'soldier', 'figure', 'taxi', 'detective', 'defender', 'youngster', 'worker', 'knight', 'rider', 'nurse', 'resident', 'employee', 'master', 'landlord', 'secret', 'miner', 'girl', 'servant', 'sergeant', 'driver', 'refugee', 'couple', 'pilot', 'woman', 'teenager', 'thief']
# *******************************************
# ['reward', 'subsidy', 'fortune', 'debt', 'spending', 'deposit', 'earnings', 'employment', 'fund', 'expenditure', 'rent', 'income', 'pension', 'profit', 'credit', 'dollar', 'loan', 'money', 'relief', 'asset', 'budget', 'insurance', 'trust', 'investment', 'wages', 'savings', 'cheque', 'employer', 'allowance', 'dividend', 'compensation', 'charity', 'membership', 'salary', 'cash', 'revenue', 'mortgage', 'payment', 'incentive']
# *******************************************
# ['respect', 'fear', 'hostility', 'curiosity', 'thanks', 'surprise', 'passion', 'beauty', 'skill', 'warmth', 'ambition', 'attention', 'desire', 'pride', 'sympathy', 'satisfaction', 'success', 'publicity', 'popularity', 'embarrassment', 'excitement', 'disappointment', 'loyalty', 'frustration', 'experience', 'enthusiasm', 'pleasure', 'contempt', 'hope', 'courage', 'confidence', 'wealth', 'friendship', 'triumph', 'guilt', 'happiness', 'trouble', 'delight', 'reputation', 'talent', 'comfort', 'anger']
# *******************************************
# ['estate', 'temple', 'ground', 'grounds', 'chapel', 'shelter', 'accommodation', 'housing', 'site', 'castle', 'land', 'facility', 'villa', 'tenant', 'mine', 'hotel', 'house', 'terrace', 'tower', 'yard', 'cottage', 'garden', 'mill', 'square', 'building', 'apartment', 'camp', 'hall', 'home', 'acre', 'farm', 'palace']
# *******************************************
# ['negotiation', 'service', 'assessment', 'scheme', 'public', 'communication', 'assistance', 'sector', 'allocation', 'improvement', 'security', 'plan', 'development', 'media', 'health', 'policy', 'project', 'resource', 'advertising', 'finance', 'implementation', 'consultation', 'strategy', 'integration', 'portfolio', 'enterprise', 'management', 'guidance', 'design', 'regulation', 'research', 'personnel', 'initiative', 'future', 'welfare', 'training', 'evaluation', 'agency', 'analysis', 'program', 'administration', 'planning', 'compliance', 'innovation', 'intelligence', 'technology', 'environment', 'joint', 'care', 'consumer', 'co-operation', 'framework']
# *******************************************
# ['electricity', 'fuel', 'equipment', 'supplies', 'safety', 'power', 'preparation', 'availability', 'treatment', 'transport', 'shortage', 'protection', 'waste', 'effectiveness', 'recovery', 'capability', 'supply', 'control', 'coal', 'production', 'balance', 'energy', 'consumption', 'pollution', 'plenty', 'distribution', 'efficiency', 'bulk', 'quality', 'lack', 'inspection', 'reduction', 'maintenance', 'delivery', 'stability', 'construction', 'demand', 'ease']
# *******************************************
# ['diana', 'alice', 'kate', 'rose', 'rachel', 'elizabeth', 'penny', 'anne', 'robyn', 'sarah', 'isabel', 'laura', 'ruth', 'caroline', 'maggie', 'marie', 'queen', 'emily', 'anna', 'mary', 'princess', 'jane', 'lily', 'blanche', 'lucy', 'lady', 'helen', 'susan']
# *******************************************
# ['bible', 'science', 'language', 'writing', 'study', 'discourse', 'architecture', 'curriculum', 'russian', 'tradition', 'culture', 'poetry', 'french', 'practice', 'religion', 'instruction', 'literature', 'philosophy', 'english', 'teaching', 'christian', 'politics', 'history']
# *******************************************
# ['word', 'diary', 'marx', 'century', 'journey', 'novel', 'book', 'plot', 'character', 'sentence', 'thesis', 'essay', 'phrase', 'verse', 'letter', 'term', 'tune', 'poem', 'fragment', 'script', 'piece', 'mystery', 'tragedy', 'name', 'myth', 'theme', 'story', 'tale']
# *******************************************
# ['white', 'collar', 'garment', 'cloth', 'skirt', 'clothes', 'green', 'sleeve', 'colour', 'hair', 'suit', 'stitch', 'dress', 'mask', 'patch', 'pocket', 'black', 'trousers', 'signature', 'shirt', 'gold', 'knot', 'belt', 'uniform', 'jacket', 'blanket', 'glove', 'seal', 'flag', 'coat', 'towel']
# *******************************************
# ['attack', 'missile', 'explosion', 'invasion', 'mission', 'fighting', 'raid', 'aircraft', 'fleet', 'bomb', 'ship', 'vessel', 'attempt', 'weapon', 'shot', 'defeat', 'flight', 'enemy', 'carrier', 'fire', 'strike', 'guard', 'troops', 'plane', 'assault', 'battle', 'launch', 'operation', 'expedition', 'crash', 'landing', 'observation', 'crew', 'force', 'helicopter', 'command', 'army', 'base']
# *******************************************
# ['photographer', 'scientist', 'researcher', 'author', 'collector', 'writer', 'practitioner', 'consultant', 'designer', 'lawyer', 'architect', 'editor', 'politician', 'historian', 'teacher', 'artist', 'expert', 'critic', 'reporter', 'accountant', 'specialist', 'actor', 'producer', 'engineer', 'poet', 'journalist', 'scholar', 'commentator', 'dancer', 'analyst']
# *******************************************
# ['position', 'speaker', 'chairman', 'defence', 'coach', 'treasury', 'delegate', 'president', 'charge', 'director', 'assembly', 'cabinet', 'appointment', 'post', 'officer', 'councillor', 'committee', 'trustee', 'ambassador', 'chief', 'leader', 'prime', 'constable', 'bishop', 'magistrate', 'commissioner', 'manager', 'board', 'chair', 'ministry', 'adviser', 'clerk', 'commander', 'secretary', 'head', 'minister', 'office', 'chancellor', 'rank', 'auditor', 'judge', 'assistant', 'staff', 'justice', 'member', 'spokesman', 'executive', 'deputy', 'solicitor', 'governor', 'organiser', 'inspector', 'council', 'representative']
# *******************************************
# ['times', 'occasion', 'interview', 'routine', 'schedule', 'hour', 'show', 'month', 'night', 'week', 'year', 'afternoon', 'channel', 'minute', 'host', 'radio', 'headline', 'morning', 'news', 'decade', 'episode', 'programme', 'session', 'time', 'spot', 'weekend', 'evening']
# *******************************************
# ['universe', 'kiss', 'past', 'ghost', 'prayer', 'silence', 'lord', 'darkness', 'dream', 'horror', 'planet', 'glory', 'stranger', 'shadow', 'earth', 'fate', 'moon', 'christ', 'dawn', 'jesus', 'love', 'truth', 'smile', 'hell', 'rage', 'soul', 'heaven', 'chaos', 'spirit', 'angel', 'sigh']
# *******************************************
# ['limitation', 'incidence', 'delay', 'damage', 'burden', 'shock', 'difficulty', 'obstacle', 'failure', 'chance', 'exposure', 'cause', 'result', 'isolation', 'threat', 'advantage', 'danger', 'harm', 'loss', 'tension', 'impact', 'consequence', 'pressure', 'effect', 'stress', 'need', 'strain', 'expense', 'potential', 'survival', 'benefit', 'risk']
# *******************************************
# ['lead', 'laugh', 'handle', 'move', 'spread', 'gain', 'step', 'play', 'pass', 'blow', 'draw', 'look', 'return', 'deal', 'forward', 'sign', 'switch', 'fight', 'stick', 'hold', 'crack', 'stand', 'trick', 'advance', 'mess', 'turn', 'kick', 'pace', 'drop', 'walk', 'start', 'change', 'drive', 'block', 'help', 'will', 'spell', 'check', 'stop', 'watch', 'call', 'back', 'break', 'counter', 'open', 'let']
# *******************************************
# ['subsidiary', 'group', 'company', 'manufacturer', 'investor', 'corp', 'stake', 'venture', 'holding', 'owner', 'brand', 'industry', 'operator', 'bank', 'shareholder', 'corporation', 'trading', 'developer', 'competitor', 'chain', 'airline', 'partnership', 'supplier', 'parent', 'firm', 'business']
# *******************************************
# ['australia', 'america', 'italy', 'german', 'india', 'germany', 'paris', 'britain', 'israel', 'continent', 'england', 'wales', 'rome', 'ireland', 'russia', 'scotland', 'kingdom', 'china', 'japan', 'europe', 'spain', 'kong', 'iraq', 'france', 'africa', 'moscow']
# *******************************************
# ['vote', 'consideration', 'discretion', 'appeal', 'recommendation', 'caution', 'opinion', 'resolution', 'remedy', 'intervention', 'action', 'enquiry', 'exercise', 'sanction', 'inquiry', 'judgement', 'decision', 'verdict', 'judgment', 'advice', 'circumstance', 'outcome', 'investigation', 'hearing', 'case']
# *******************************************
# ['pound', 'estimate', 'length', 'tonne', 'quantity', 'accuracy', 'thousand', 'million', 'rating', 'size', 'turnover', 'speed', 'average', 'hundred', 'height', 'cost', 'measure', 'value', 'fraction', 'limit', 'proportion', 'interval', 'minimum', 'amount', 'level', 'index', 'ratio', 'rate', 'total', 'load', 'seconds', 'lifespan', 'metre', 'scale', 'concentration', 'increase', 'margin', 'dose', 'range', 'excess', 'strength', 'inch', 'weight', 'depth', 'mass', 'number', 'capacity', 'maximum', 'distance', 'percentage']
# *******************************************
# ['season', 'team', 'major', 'professional', 'goal', 'match', 'football', 'trophy', 'grade', 'division', 'player', 'award', 'contest', 'youth', 'test', 'wicket', 'bowl', 'medal', 'league', 'rally', 'career', 'prize', 'winner', 'club', 'series', 'event', 'challenge', 'squad', 'second', 'champion', 'competition', 'tour', 'round', 'title', 'victory', 'class', 'game', 'final', 'clash', 'draft', 'championship', 'promotion', 'tournament', 'conference', 'qualification', 'world', 'race', 'sport']
# *******************************************
# ['disc', 'lift', 'clock', 'stair', 'wall', 'roof', 'plate', 'doorway', 'tray', 'ride', 'frame', 'horse', 'wire', 'lamp', 'window', 'engine', 'motor', 'bike', 'roll', 'rope', 'slide', 'carriage', 'pack', 'curtain', 'ceiling', 'boat', 'ball', 'fence', 'shaft', 'panel', 'tank', 'front', 'vehicle', 'button', 'floor', 'ladder', 'gear', 'bench', 'pool', 'tube', 'bucket', 'lorry', 'wheel', 'ring', 'door', 'flat', 'pitch', 'deck', 'battery', 'wing', 'pipe', 'barrel', 'alarm', 'truck']
# *******************************************

# %%
print("Random samples from Deps")
for i in range(num_clustersd):
    print(word_dict3[i])
    print("*******************************************")
# Out:
# Random samples from Deps
# ['past', 'conservative', 'major', 'professional', 'public', 'german', 'grade', 'current', 'russian', 'other', 'french', 'american', 'prime', 'black', 'present', 'future', 'second', 'secret', 'best', 'english', 'christian', 'joint']
# *******************************************
# ['order', 'clause', 'scheme', 'statute', 'directive', 'curriculum', 'schedule', 'bill', 'resolution', 'plan', 'policy', 'project', 'provision', 'contract', 'strategy', 'agenda', 'legislation', 'constitution', 'proposal', 'campaign', 'arrangement', 'rule', 'initiative', 'charter', 'effort', 'treaty', 'programme', 'program', 'partnership', 'guideline', 'agreement', 'decree', 'amendment']
# *******************************************
# ['paint', 'lift', 'handle', 'slice', 'track', 'brush', 'ride', 'play', 'blow', 'hook', 'cook', 'tear', 'roll', 'bomb', 'slide', 'forward', 'stitch', 'pack', 'fight', 'cast', 'stick', 'shot', 'contact', 'crack', 'trick', 'load', 'holding', 'punch', 'grip', 'cross', 'kick', 'strike', 'walk', 'drive', 'hunt', 'chip', 'filter', 'touch', 'watch', 'pitch', 'lock', 'score', 'seal', 'trap']
# *******************************************
# ['position', 'achievement', 'existence', 'employment', 'occupation', 'participation', 'activity', 'expertise', 'skill', 'contribution', 'action', 'identity', 'exposure', 'success', 'role', 'involvement', 'popularity', 'status', 'career', 'experience', 'duty', 'performance', 'appearance', 'interest', 'membership', 'presence', 'reputation', 'coverage', 'talent', 'commitment', 'profession', 'influence', 'life']
# *******************************************
# ['importance', 'incidence', 'length', 'momentum', 'accuracy', 'power', 'rating', 'size', 'speed', 'height', 'extent', 'location', 'ability', 'sensitivity', 'value', 'volume', 'availability', 'level', 'effectiveness', 'emission', 'output', 'ratio', 'complexity', 'capability', 'rate', 'balance', 'angle', 'depths', 'energy', 'lifespan', 'degree', 'worth', 'efficiency', 'pressure', 'quality', 'frequency', 'rank', 'strength', 'validity', 'lack', 'weight', 'temperature', 'depth', 'capacity', 'significance', 'distance', 'merit', 'scope', 'ease', 'intensity']
# *******************************************
# ['diana', 'alice', 'kate', 'rachel', 'elizabeth', 'anne', 'robyn', 'sarah', 'isabel', 'laura', 'ruth', 'caroline', 'maggie', 'marie', 'emily', 'anna', 'mary', 'jane', 'lily', 'blanche', 'lucy', 'helen', 'susan']
# *******************************************
# ['card', 'disc', 'collar', 'garment', 'tile', 'clock', 'cloth', 'pole', 'plate', 'skirt', 'needle', 'tray', 'clothes', 'arrow', 'sleeve', 'wire', 'beam', 'lamp', 'suit', 'bottle', 'rope', 'envelope', 'sword', 'carpet', 'phone', 'pair', 'dress', 'ball', 'mask', 'tape', 'disk', 'patch', 'fist', 'wicket', 'blade', 'bullet', 'trousers', 'metal', 'knife', 'glass', 'button', 'pillow', 'shirt', 'gear', 'strip', 'tube', 'candle', 'knot', 'wheel', 'ring', 'camera', 'belt', 'inch', 'nail', 'uniform', 'jacket', 'blanket', 'glove', 'torch', 'shoe', 'boot', 'sheet', 'string', 'pipe', 'barrel', 'machine', 'mirror', 'telephone', 'flag', 'cigarette', 'coat', 'guitar', 'towel', 'shell']
# *******************************************
# ['stair', 'wall', 'roof', 'doorway', 'gate', 'opening', 'window', 'curtain', 'ceiling', 'fence', 'shaft', 'entrance', 'tunnel', 'floor', 'pavement', 'terrace', 'tower', 'door', 'corridor']
# *******************************************
# ['speaker', 'chairman', 'democrat', 'coach', 'delegate', 'president', 'director', 'captain', 'official', 'officer', 'supporter', 'councillor', 'trustee', 'ambassador', 'chief', 'leader', 'constable', 'bishop', 'magistrate', 'commissioner', 'manager', 'defender', 'chair', 'adviser', 'clerk', 'commander', 'secretary', 'minister', 'master', 'chancellor', 'auditor', 'judge', 'candidate', 'assistant', 'justice', 'member', 'spokesman', 'executive', 'deputy', 'solicitor', 'sergeant', 'governor', 'organiser', 'inspector', 'representative']
# *******************************************
# ['characteristic', 'problem', 'scene', 'norm', 'factor', 'symbol', 'symptom', 'tendency', 'tradition', 'pattern', 'path', 'situation', 'origin', 'wave', 'combination', 'sequence', 'custom', 'process', 'result', 'practice', 'tactic', 'matter', 'aspect', 'type', 'consequence', 'topic', 'effect', 'mode', 'term', 'technique', 'reaction', 'trend', 'kind', 'task', 'element', 'phase', 'phenomenon', 'circumstance', 'component', 'cycle', 'outcome', 'theme']
# *******************************************
# ['personality', 'gesture', 'background', 'tone', 'sense', 'expression', 'character', 'atmosphere', 'mood', 'habit', 'behaviour', 'context', 'vision', 'motion', 'direction', 'pace', 'fashion', 'climate', 'attitude', 'style', 'tune', 'manner', 'sound', 'rhythm', 'nature', 'spirit', 'voice', 'environment', 'flavour', 'taste']
# *******************************************
# ['estate', 'cliff', 'road', 'lake', 'mountain', 'street', 'green', 'field', 'ward', 'hill', 'site', 'castle', 'reserve', 'ridge', 'line', 'villa', 'shelf', 'mine', 'beach', 'park', 'lane', 'trail', 'peak', 'island', 'river', 'canal', 'yard', 'garden', 'bridge', 'railway', 'mill', 'square', 'pond', 'acre', 'stream', 'farm']
# *******************************************
# ['tribunal', 'parliament', 'meeting', 'association', 'referendum', 'summit', 'assembly', 'convention', 'union', 'congress', 'authority', 'committee', 'seat', 'panel', 'board', 'society', 'trust', 'commission', 'club', 'foundation', 'jury', 'session', 'constituency', 'council', 'conference', 'chapter', 'court']
# *******************************************
# ['section', 'collection', 'article', 'instance', 'image', 'file', 'material', 'publication', 'item', 'statue', 'resource', 'advertising', 'portrait', 'print', 'information', 'entry', 'copy', 'signature', 'paper', 'papers', 'video', 'presentation', 'edition', 'advertisement', 'text', 'poster', 'photograph', 'leaflet', 'page', 'piece', 'picture', 'example', 'content', 'version', 'description', 'memory', 'contents', 'name', 'source']
# *******************************************
# ['vendor', 'client', 'collector', 'holder', 'player', 'manufacturer', 'agent', 'investor', 'maker', 'dealer', 'seller', 'host', 'customer', 'owner', 'tenant', 'operator', 'buyer', 'receiver', 'shareholder', 'employee', 'employer', 'producer', 'developer', 'competitor', 'creditor', 'publisher', 'boss', 'landlord', 'supplier', 'driver', 'parent', 'purchaser', 'consumer']
# *******************************************
# ['defence', 'statistics', 'assessment', 'safety', 'growth', 'preparation', 'improvement', 'evolution', 'selection', 'expansion', 'development', 'treatment', 'accommodation', 'health', 'housing', 'discipline', 'recovery', 'implementation', 'examination', 'production', 'succession', 'management', 'possession', 'distribution', 'regulation', 'ownership', 'research', 'economy', 'welfare', 'training', 'pursuit', 'inspection', 'maintenance', 'delivery', 'evaluation', 'analysis', 'planning', 'education', 'survival', 'construction', 'innovation', 'intelligence', 'promotion', 'generation', 'care']
# *******************************************
# ['mist', 'wind', 'darkness', 'water', 'shadow', 'breeze', 'rain', 'tide', 'sunlight', 'snow', 'weather', 'flame', 'fire', 'dust', 'storm', 'dawn', 'terror', 'light', 'smoke', 'heat', 'chaos', 'cloud', 'sand', 'noise']
# *******************************************
# ['patrick', 'robert', 'eliot', 'francis', 'richard', 'martin', 'scott', 'tony', 'luke', 'mark', 'philip', 'joseph', 'willie', 'benjamin', 'nigel', 'charles', 'george', 'david', 'henry', 'mungo', 'graham', 'adam', 'charlie', 'paul', 'stephen', 'will', 'michael', 'edward', 'john', 'peter', 'william', 'james', 'jack', 'simon', 'thomas', 'harry']
# *******************************************
# ['replacement', 'establishment', 'death', 'completion', 'appointment', 'departure', 'withdrawal', 'resignation', 'formation', 'arrest', 'passage', 'adoption', 'creation', 'election', 'removal', 'arrival', 'retirement', 'birth', 'acquisition', 'absence', 'discovery', 'closure', 'introduction']
# *******************************************
# ['photographer', 'scientist', 'researcher', 'author', 'writer', 'practitioner', 'consultant', 'designer', 'lawyer', 'architect', 'editor', 'politician', 'historian', 'teacher', 'artist', 'expert', 'critic', 'observer', 'fellow', 'detective', 'reporter', 'accountant', 'specialist', 'actor', 'engineer', 'poet', 'journalist', 'scholar', 'commentator', 'analyst']
# *******************************************
# ['proceedings', 'dispute', 'report', 'allegation', 'controversy', 'appeal', 'announcement', 'petition', 'charge', 'opinion', 'remedy', 'criticism', 'argument', 'objection', 'rumour', 'enquiry', 'request', 'declaration', 'sanction', 'inquiry', 'issue', 'consensus', 'judgement', 'decision', 'verdict', 'judgment', 'speculation', 'debate', 'offence', 'complaint', 'statement', 'conviction', 'scandal', 'demonstration', 'discussion', 'injunction', 'investigation', 'protest', 'hearing', 'trial', 'prosecution', 'case']
# *******************************************
# ['season', 'times', 'occasion', 'lifetime', 'summer', 'anniversary', 'thousand', 'million', 'century', 'spring', 'winter', 'hundred', 'mile', 'hour', 'quarter', 'month', 'night', 'week', 'autumn', 'year', 'afternoon', 'middle', 'minute', 'seconds', 'metre', 'morning', 'beginning', 'decade', 'course', 'period', 'half', 'while', 'couple', 'time', 'weekend', 'evening', 'moment']
# *******************************************
# ['limitation', 'addition', 'difference', 'comparison', 'relation', 'extension', 'inequality', 'distinction', 'error', 'connection', 'variation', 'preference', 'relationship', 'contrast', 'advantage', 'constraint', 'equivalent', 'contradiction', 'reduction', 'discrimination', 'barrier', 'restriction']
# *******************************************
# ['pound', 'exchange', 'fortune', 'coin', 'deposit', 'import', 'fund', 'penny', 'bond', 'rent', 'lease', 'market', 'transaction', 'share', 'credit', 'dollar', 'loan', 'finance', 'stake', 'money', 'property', 'purchase', 'gift', 'cheque', 'gold', 'trading', 'monopoly', 'stock', 'export', 'currency', 'trade', 'cash', 'mortgage', 'sale', 'grant']
# *******************************************
# ['penalty', 'requirement', 'reward', 'option', 'goal', 'intention', 'obstacle', 'alternative', 'chance', 'prospect', 'opportunity', 'priority', 'threat', 'ideal', 'punishment', 'objective', 'responsibility', 'right', 'wish', 'privilege', 'motive', 'choice', 'prospects', 'hope', 'possibility', 'reason', 'need', 'necessity', 'obligation', 'potential', 'purpose', 'promise', 'means', 'incentive']
# *******************************************
# ['temple', 'hospital', 'university', 'museum', 'gallery', 'chapel', 'complex', 'library', 'workshop', 'clinic', 'school', 'facility', 'headquarters', 'studio', 'institute', 'hotel', 'prison', 'shop', 'house', 'office', 'plant', 'cathedral', 'centre', 'church', 'store', 'building', 'camp', 'hall', 'airport', 'factory', 'home', 'theatre', 'college', 'laboratory', 'base', 'restaurant', 'palace']
# *******************************************
# ['fabric', 'colour', 'hair', 'heart', 'crop', 'flower', 'tongue', 'brain', 'skin', 'vein', 'strand', 'limb', 'blood', 'layer', 'palm', 'fibre', 'surface', 'leaf', 'core', 'bone', 'muscle', 'tissue', 'flesh', 'soil', 'root', 'stem', 'grass', 'nerve']
# *******************************************
# ['defendant', 'person', 'people', 'subject', 'participant', 'baby', 'plaintiff', 'offender', 'user', 'enemy', 'child', 'viewer', 'opponent', 'reader', 'voter', 'prey', 'individual', 'audience', 'target', 'victim', 'witness', 'applicant', 'patient']
# *******************************************
# ['beer', 'sugar', 'rabbit', 'salt', 'fish', 'cream', 'seed', 'meat', 'food', 'juice', 'coffee', 'potato', 'apple', 'coal', 'drink', 'grain', 'sheep', 'cattle', 'fruit', 'alcohol', 'lamb', 'champagne', 'wine', 'bread', 'milk']
# *******************************************
# ['volunteer', 'ghost', 'insider', 'prisoner', 'citizen', 'living', 'gentleman', 'guest', 'farmer', 'visitor', 'hero', 'killer', 'stranger', 'scot', 'traveller', 'tourist', 'policeman', 'student', 'priest', 'doctor', 'soldier', 'youngster', 'worker', 'peasant', 'inhabitant', 'rider', 'nurse', 'resident', 'princess', 'miner', 'girl', 'servant', 'refugee', 'pilot', 'woman', 'teenager', 'dancer', 'lady', 'angel', 'thief']
# *******************************************
# ['partner', 'rival', 'successor', 'colleague', 'mother', 'ally', 'wife', 'daughter', 'neighbour', 'companion', 'father', 'relative', 'cousin', 'husband', 'sister', 'brother', 'lover', 'pupil', 'friend']
# *******************************************
# ['white', 'clinton', 'bell', 'marx', 'duke', 'march', 'rose', 'wilson', 'lord', 'johnson', 'clarke', 'thatcher', 'kelly', 'april', 'ford', 'lewis', 'pope', 'king', 'z', 'emperor', 'june', 'queen', 'christ', 'gorbachev', 'knight', 'williams', 'washington', 'baker', 'miller', 'february', 'morgan', 'jesus', 'corbett', 'stone', 'earl', 'bush', 'hitler', 'wright', 'brown', 'bull', 'kinnock', 'jones', 'walker', 'smith', 'howard', 'athelstan', 'jackson', 'prince', 'wood', 'taylor']
# *******************************************
# ['account', 'estimate', 'review', 'detail', 'profile', 'frame', 'study', 'measure', 'register', 'plot', 'shape', 'outline', 'cover', 'look', 'document', 'trace', 'recording', 'record', 'test', 'catalogue', 'format', 'setting', 'list', 'sample', 'form', 'figure', 'sort', 'date', 'scale', 'design', 'chart', 'glimpse', 'guide', 'fragment', 'search', 'feature', 'address', 'draft', 'display', 'survey']
# *******************************************
# ['uncertainty', 'fear', 'hostility', 'attraction', 'curiosity', 'violence', 'surprise', 'caution', 'passion', 'fault', 'ambition', 'difficulty', 'desire', 'pride', 'sympathy', 'satisfaction', 'embarrassment', 'excitement', 'disappointment', 'loyalty', 'awareness', 'danger', 'frustration', 'dilemma', 'enthusiasm', 'pleasure', 'tension', 'weakness', 'conflict', 'confusion', 'contempt', 'stress', 'willingness', 'courage', 'confidence', 'anxiety', 'faith', 'bias', 'friendship', 'concern', 'guilt', 'trouble', 'suspicion', 'anger']
# *******************************************
# ['drug', 'acid', 'signal', 'chemical', 'gene', 'compound', 'particle', 'weapon', 'object', 'entity', 'cluster', 'body', 'animal', 'insect', 'female', 'bacterium', 'medium', 'monster', 'adult', 'creature', 'virus', 'molecule', 'bird', 'protein', 'mouse', 'specimen', 'species', 'human', 'instrument', 'organ', 'male', 'stimulus', 'organism', 'cell', 'substance', 'computer']
# *******************************************
# ['subsidy', 'debt', 'spending', 'turnover', 'burden', 'earnings', 'allocation', 'cost', 'surplus', 'liability', 'expenditure', 'income', 'pension', 'shortage', 'waste', 'profit', 'premium', 'deficit', 'portfolio', 'asset', 'price', 'budget', 'insurance', 'investment', 'consumption', 'wages', 'pollution', 'savings', 'allowance', 'dividend', 'expense', 'compensation', 'inflation', 'wealth', 'salary', 'revenue', 'demand', 'payment', 'unemployment', 'risk']
# *******************************************
# ['attack', 'explosion', 'disaster', 'damage', 'invasion', 'fighting', 'raid', 'revolution', 'crisis', 'incident', 'struggle', 'failure', 'boom', 'destruction', 'defeat', 'rise', 'decline', 'recession', 'fall', 'loss', 'impact', 'assault', 'battle', 'killing', 'collapse', 'crash', 'murder', 'victory', 'flood', 'landing', 'triumph', 'tragedy', 'clash']
# *******************************************
# ['bible', 'science', 'diary', 'film', 'language', 'writing', 'novel', 'song', 'movie', 'composition', 'discourse', 'architecture', 'dialogue', 'book', 'culture', 'poetry', 'lecture', 'speech', 'medicine', 'drama', 'music', 'painting', 'religion', 'essay', 'drawing', 'verse', 'literature', 'philosophy', 'poem', 'episode', 'script', 'mystery', 'teaching', 'dance', 'history', 'myth', 'story', 'tale']
# *******************************************
# ['conception', 'finding', 'interpretation', 'knowledge', 'basis', 'ideology', 'explanation', 'grounds', 'meaning', 'principle', 'thinking', 'emphasis', 'being', 'premise', 'virtue', 'proof', 'view', 'thesis', 'perspective', 'hypothesis', 'thought', 'approach', 'evidence', 'concept', 'impression', 'theory', 'implication', 'belief', 'expectation', 'perception', 'point', 'suggestion', 'notion', 'stance', 'reflection', 'understanding', 'assumption', 'conclusion', 'reading', 'fact', 'observation', 'doctrine', 'definition', 'idea', 'proposition']
# *******************************************
# ['missile', 'cable', 'craft', 'journey', 'horse', 'passenger', 'aircraft', 'engine', 'fleet', 'trip', 'motor', 'bike', 'ship', 'vessel', 'carriage', 'boat', 'flight', 'tank', 'packet', 'taxi', 'carrier', 'vehicle', 'plane', 'train', 'lorry', 'expedition', 'rail', 'battery', 'crew', 'helicopter', 'truck']
# *******************************************
